# %%
from kafka import KafkaConsumer
import json

# %%
bootstrap_servers = "mydb.iptime.org:9092"
topic_name = "smartcar-data"

consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers = bootstrap_servers,
    auto_offset_reset = "latest", 
    enable_auto_commit = True,
    group_id = "smartcar-group",
    value_deserializer=lambda x: json.loads(x.decode("utf-8"))
)

print("데이터 가져오는중")

for message in consumer:
    print(f"Received message: {message.value}")
# Out:
# 데이터 가져오는중
# Received message: {'car_id': '3134/100000', 'speed': 103.0, 'latitude': 35.017916, 'longitude': 129.140776, 'timestamp': 1746608038.6631258}
# Received message: {'car_id': '3135/100000', 'speed': 102.5, 'latitude': 35.017883, 'longitude': 129.140586, 'timestamp': 1746608039.1661892}
# Received message: {'car_id': '3136/100000', 'speed': 102.9, 'latitude': 35.017854, 'longitude': 129.140392, 'timestamp': 1746608039.669245}
# Received message: {'car_id': '3137/100000', 'speed': 102.6, 'latitude': 35.017828, 'longitude': 129.140199, 'timestamp': 1746608040.1723366}
# Received message: {'car_id': '3138/100000', 'speed': 102.9, 'latitude': 35.017803, 'longitude': 129.140005, 'timestamp': 1746608040.6750576}
# Received message: {'car_id': '3139/100000', 'speed': 103.1, 'latitude': 35.017787, 'longitude': 129.139807, 'timestamp': 1746608041.1781933}
# Received message: {'car_id': '3140/100000', 'speed': 102.9, 'latitude': 35.017768, 'longitude': 129.139611, 'timestamp': 1746608041.681296}
# Received message: {'car_id': '3141/100000', 'speed': 103.2, 'latitude': 35.017742, 'longitude': 129.139416, 'timestamp': 1746608042.184213}
# Received message: {'car_id': '3142/100000', 'speed': 102.7, 'latitude': 35.017715, 'longitude': 129.139223, 'timestamp': 1746608042.6872537}
# Received message: {'car_id': '3143/100000', 'speed': 102.5, 'latitude': 35.017689, 'longitude': 129.139029, 'timestamp': 1746608043.1903603}
# Received message: {'car_id': '3144/100000', 'speed': 102.5, 'latitude': 35.017662, 'longitude': 129.138836, 'timestamp': 1746608043.693965}
# Received message: {'car_id': '3145/100000', 'speed': 102.9, 'latitude': 35.017629, 'longitude': 129.138645, 'timestamp': 1746608044.1970012}
# Received message: {'car_id': '3146/100000', 'speed': 102.4, 'latitude': 35.017586, 'longitude': 129.138459, 'timestamp': 1746608044.6986673}
# Received message: {'car_id': '3147/100000', 'speed': 102.0, 'latitude': 35.017543, 'longitude': 129.138274, 'timestamp': 1746608045.2018504}
# Received message: {'car_id': '3148/100000', 'speed': 102.4, 'latitude': 35.017498, 'longitude': 129.138089, 'timestamp': 1746608045.7047462}
# Received message: {'car_id': '3149/100000', 'speed': 102.3, 'latitude': 35.017463, 'longitude': 129.137899, 'timestamp': 1746608046.207582}
# Received message: {'car_id': '3150/100000', 'speed': 102.1, 'latitude': 35.01743, 'longitude': 129.137709, 'timestamp': 1746608046.7106662}
# Received message: {'car_id': '3151/100000', 'speed': 102.1, 'latitude': 35.017388, 'longitude': 129.137523, 'timestamp': 1746608047.2135637}
# Received message: {'car_id': '3152/100000', 'speed': 102.4, 'latitude': 35.017347, 'longitude': 129.137336, 'timestamp': 1746608047.7166622}
# Received message: {'car_id': '3153/100000', 'speed': 102.5, 'latitude': 35.017305, 'longitude': 129.13715, 'timestamp': 1746608048.2197735}
# Received message: {'car_id': '3154/100000', 'speed': 102.8, 'latitude': 35.017266, 'longitude': 129.136961, 'timestamp': 1746608048.722938}
# Received message: {'car_id': '3155/100000', 'speed': 102.6, 'latitude': 35.017227, 'longitude': 129.136773, 'timestamp': 1746608049.2259731}
# Received message: {'car_id': '3156/100000', 'speed': 103.0, 'latitude': 35.017182, 'longitude': 129.136587, 'timestamp': 1746608049.7290215}
# Received message: {'car_id': '3157/100000', 'speed': 103.2, 'latitude': 35.017133, 'longitude': 129.136403, 'timestamp': 1746608050.230679}
# Received message: {'car_id': '3158/100000', 'speed': 102.9, 'latitude': 35.01709, 'longitude': 129.136216, 'timestamp': 1746608050.7337966}
# Received message: {'car_id': '3159/100000', 'speed': 102.5, 'latitude': 35.017045, 'longitude': 129.136031, 'timestamp': 1746608051.236952}
# Received message: {'car_id': '3160/100000', 'speed': 102.5, 'latitude': 35.017001, 'longitude': 129.135846, 'timestamp': 1746608051.7384803}
# Received message: {'car_id': '3161/100000', 'speed': 102.3, 'latitude': 35.016958, 'longitude': 129.13566, 'timestamp': 1746608052.2415862}
# Received message: {'car_id': '3162/100000', 'speed': 102.2, 'latitude': 35.016914, 'longitude': 129.135475, 'timestamp': 1746608052.7445955}
# Received message: {'car_id': '3163/100000', 'speed': 102.3, 'latitude': 35.016873, 'longitude': 129.135288, 'timestamp': 1746608053.2476697}
# Received message: {'car_id': '3164/100000', 'speed': 102.2, 'latitude': 35.016831, 'longitude': 129.135102, 'timestamp': 1746608053.7505543}
# Received message: {'car_id': '3165/100000', 'speed': 102.3, 'latitude': 35.01679, 'longitude': 129.134916, 'timestamp': 1746608054.253608}
# Received message: {'car_id': '3166/100000', 'speed': 102.6, 'latitude': 35.016739, 'longitude': 129.134734, 'timestamp': 1746608054.7566986}
# Received message: {'car_id': '3167/100000', 'speed': 103.0, 'latitude': 35.016682, 'longitude': 129.134556, 'timestamp': 1746608055.259984}
# Received message: {'car_id': '3168/100000', 'speed': 103.4, 'latitude': 35.016632, 'longitude': 129.134372, 'timestamp': 1746608055.7631426}
# Received message: {'car_id': '3169/100000', 'speed': 102.9, 'latitude': 35.01658, 'longitude': 129.134191, 'timestamp': 1746608056.2645626}
# Received message: {'car_id': '3170/100000', 'speed': 102.7, 'latitude': 35.016523, 'longitude': 129.134014, 'timestamp': 1746608056.7676516}
# Received message: {'car_id': '3171/100000', 'speed': 102.3, 'latitude': 35.016466, 'longitude': 129.133836, 'timestamp': 1746608057.2707765}
# Received message: {'car_id': '3172/100000', 'speed': 102.2, 'latitude': 35.016409, 'longitude': 129.133661, 'timestamp': 1746608057.7739875}
# Received message: {'car_id': '3173/100000', 'speed': 102.2, 'latitude': 35.016345, 'longitude': 129.13349, 'timestamp': 1746608058.2770057}
# Received message: {'car_id': '3174/100000', 'speed': 102.2, 'latitude': 35.01629, 'longitude': 129.133312, 'timestamp': 1746608058.7800722}
# Received message: {'car_id': '3175/100000', 'speed': 101.7, 'latitude': 35.01623, 'longitude': 129.133139, 'timestamp': 1746608059.2817242}
# Received message: {'car_id': '3176/100000', 'speed': 101.4, 'latitude': 35.016167, 'longitude': 129.13297, 'timestamp': 1746608059.7830234}
# Received message: {'car_id': '3177/100000', 'speed': 101.2, 'latitude': 35.016102, 'longitude': 129.132802, 'timestamp': 1746608060.2860608}
# Received message: {'car_id': '3178/100000', 'speed': 101.0, 'latitude': 35.016033, 'longitude': 129.132639, 'timestamp': 1746608060.7875047}
# Received message: {'car_id': '3179/100000', 'speed': 100.8, 'latitude': 35.015973, 'longitude': 129.132468, 'timestamp': 1746608061.2893105}
# Received message: {'car_id': '3180/100000', 'speed': 100.4, 'latitude': 35.015913, 'longitude': 129.132299, 'timestamp': 1746608061.7923808}
# Received message: {'car_id': '3181/100000', 'speed': 100.8, 'latitude': 35.015856, 'longitude': 129.132126, 'timestamp': 1746608062.2936924}
# Received message: {'car_id': '3182/100000', 'speed': 101.1, 'latitude': 35.015791, 'longitude': 129.131958, 'timestamp': 1746608062.7947426}
# Received message: {'car_id': '3183/100000', 'speed': 100.8, 'latitude': 35.01573, 'longitude': 129.131788, 'timestamp': 1746608063.2979586}
# Received message: {'car_id': '3184/100000', 'speed': 100.4, 'latitude': 35.015671, 'longitude': 129.131618, 'timestamp': 1746608063.8010387}
# Received message: {'car_id': '3185/100000', 'speed': 100.7, 'latitude': 35.015602, 'longitude': 129.131455, 'timestamp': 1746608064.3041005}
# Received message: {'car_id': '3186/100000', 'speed': 100.2, 'latitude': 35.015527, 'longitude': 129.1313, 'timestamp': 1746608064.8071408}
# Received message: {'car_id': '3187/100000', 'speed': 100.2, 'latitude': 35.015449, 'longitude': 129.131149, 'timestamp': 1746608065.310207}
# Received message: {'car_id': '3188/100000', 'speed': 100.0, 'latitude': 35.015378, 'longitude': 129.130991, 'timestamp': 1746608065.8133092}
# Received message: {'car_id': '3189/100000', 'speed': 99.9, 'latitude': 35.015304, 'longitude': 129.130835, 'timestamp': 1746608066.3163323}
# Received message: {'car_id': '3190/100000', 'speed': 99.5, 'latitude': 35.015236, 'longitude': 129.130674, 'timestamp': 1746608066.8190227}
# Received message: {'car_id': '3191/100000', 'speed': 99.5, 'latitude': 35.015167, 'longitude': 129.130515, 'timestamp': 1746608067.3206003}
# Received message: {'car_id': '3192/100000', 'speed': 99.6, 'latitude': 35.015103, 'longitude': 129.13035, 'timestamp': 1746608067.8234928}
# Received message: {'car_id': '3193/100000', 'speed': 99.4, 'latitude': 35.015034, 'longitude': 129.130191, 'timestamp': 1746608068.3250003}
# Received message: {'car_id': '3194/100000', 'speed': 99.1, 'latitude': 35.014967, 'longitude': 129.13003, 'timestamp': 1746608068.8265233}
# Received message: {'car_id': '3195/100000', 'speed': 98.6, 'latitude': 35.014905, 'longitude': 129.129866, 'timestamp': 1746608069.3295436}
# Received message: {'car_id': '3196/100000', 'speed': 98.3, 'latitude': 35.014851, 'longitude': 129.129696, 'timestamp': 1746608069.8325663}
# Received message: {'car_id': '3197/100000', 'speed': 98.0, 'latitude': 35.014804, 'longitude': 129.129521, 'timestamp': 1746608070.3356721}
# Received message: {'car_id': '3198/100000', 'speed': 97.7, 'latitude': 35.014754, 'longitude': 129.129349, 'timestamp': 1746608070.838729}
# Received message: {'car_id': '3199/100000', 'speed': 97.7, 'latitude': 35.014708, 'longitude': 129.129175, 'timestamp': 1746608071.3417845}
# Received message: {'car_id': '3200/100000', 'speed': 97.5, 'latitude': 35.014668, 'longitude': 129.128998, 'timestamp': 1746608071.8449137}
# Received message: {'car_id': '3201/100000', 'speed': 97.2, 'latitude': 35.014625, 'longitude': 129.128822, 'timestamp': 1746608072.347984}
# Received message: {'car_id': '3202/100000', 'speed': 96.8, 'latitude': 35.01459, 'longitude': 129.128644, 'timestamp': 1746608072.8510087}
# Received message: {'car_id': '3203/100000', 'speed': 97.2, 'latitude': 35.014547, 'longitude': 129.128469, 'timestamp': 1746608073.352699}
# Received message: {'car_id': '3204/100000', 'speed': 96.8, 'latitude': 35.014502, 'longitude': 129.128296, 'timestamp': 1746608073.8557184}
# Received message: {'car_id': '3205/100000', 'speed': 96.7, 'latitude': 35.014459, 'longitude': 129.128121, 'timestamp': 1746608074.3586833}
# Received message: {'car_id': '3206/100000', 'speed': 96.6, 'latitude': 35.014422, 'longitude': 129.127944, 'timestamp': 1746608074.859982}
# Received message: {'car_id': '3207/100000', 'speed': 96.5, 'latitude': 35.014378, 'longitude': 129.127771, 'timestamp': 1746608075.3630707}
# Received message: {'car_id': '3208/100000', 'speed': 96.2, 'latitude': 35.014341, 'longitude': 129.127595, 'timestamp': 1746608075.8647454}
# Received message: {'car_id': '3209/100000', 'speed': 95.8, 'latitude': 35.014312, 'longitude': 129.127415, 'timestamp': 1746608076.367737}
# Received message: {'car_id': '3210/100000', 'speed': 96.1, 'latitude': 35.014287, 'longitude': 129.127234, 'timestamp': 1746608076.8708572}
# Received message: {'car_id': '3211/100000', 'speed': 96.5, 'latitude': 35.014262, 'longitude': 129.127052, 'timestamp': 1746608077.3739958}
# Received message: {'car_id': '3212/100000', 'speed': 96.3, 'latitude': 35.014236, 'longitude': 129.126871, 'timestamp': 1746608077.8770192}
# Received message: {'car_id': '3213/100000', 'speed': 96.8, 'latitude': 35.014214, 'longitude': 129.126688, 'timestamp': 1746608078.3786979}
# Received message: {'car_id': '3214/100000', 'speed': 96.5, 'latitude': 35.014195, 'longitude': 129.126504, 'timestamp': 1746608078.8821814}
# Received message: {'car_id': '3215/100000', 'speed': 96.2, 'latitude': 35.01417, 'longitude': 129.126323, 'timestamp': 1746608079.3837137}
# Received message: {'car_id': '3216/100000', 'speed': 96.5, 'latitude': 35.014143, 'longitude': 129.126142, 'timestamp': 1746608079.8868032}
# Received message: {'car_id': '3217/100000', 'speed': 97.0, 'latitude': 35.014119, 'longitude': 129.125959, 'timestamp': 1746608080.3897438}
# Received message: {'car_id': '3218/100000', 'speed': 97.0, 'latitude': 35.014097, 'longitude': 129.125775, 'timestamp': 1746608080.8928027}
# Received message: {'car_id': '3219/100000', 'speed': 96.6, 'latitude': 35.014066, 'longitude': 129.125595, 'timestamp': 1746608081.396107}
# Received message: {'car_id': '3220/100000', 'speed': 96.4, 'latitude': 35.01403, 'longitude': 129.125418, 'timestamp': 1746608081.8978603}
# Received message: {'car_id': '3221/100000', 'speed': 96.9, 'latitude': 35.013991, 'longitude': 129.125241, 'timestamp': 1746608082.4009066}
# Received message: {'car_id': '3222/100000', 'speed': 96.5, 'latitude': 35.013944, 'longitude': 129.125069, 'timestamp': 1746608082.903976}
# Received message: {'car_id': '3223/100000', 'speed': 96.2, 'latitude': 35.013889, 'longitude': 129.124904, 'timestamp': 1746608083.4070137}
# Received message: {'car_id': '3224/100000', 'speed': 95.9, 'latitude': 35.013837, 'longitude': 129.124738, 'timestamp': 1746608083.9086838}
# Received message: {'car_id': '3225/100000', 'speed': 96.4, 'latitude': 35.013776, 'longitude': 129.124578, 'timestamp': 1746608084.4114916}
# Received message: {'car_id': '3226/100000', 'speed': 95.9, 'latitude': 35.013713, 'longitude': 129.124421, 'timestamp': 1746608084.9145565}
# Received message: {'car_id': '3227/100000', 'speed': 96.1, 'latitude': 35.013654, 'longitude': 129.124259, 'timestamp': 1746608085.417498}
# Received message: {'car_id': '3228/100000', 'speed': 96.1, 'latitude': 35.013589, 'longitude': 129.124104, 'timestamp': 1746608085.921025}
# Received message: {'car_id': '3229/100000', 'speed': 95.9, 'latitude': 35.013518, 'longitude': 129.123954, 'timestamp': 1746608086.424322}
# Received message: {'car_id': '3230/100000', 'speed': 95.7, 'latitude': 35.013446, 'longitude': 129.123807, 'timestamp': 1746608086.9274552}
# Received message: {'car_id': '3231/100000', 'speed': 96.2, 'latitude': 35.01337, 'longitude': 129.123663, 'timestamp': 1746608087.4305341}
# Received message: {'car_id': '3232/100000', 'speed': 95.8, 'latitude': 35.013296, 'longitude': 129.123518, 'timestamp': 1746608087.9335809}
# Received message: {'car_id': '3233/100000', 'speed': 95.8, 'latitude': 35.013227, 'longitude': 129.123367, 'timestamp': 1746608088.4365535}
# Received message: {'car_id': '3234/100000', 'speed': 96.1, 'latitude': 35.013158, 'longitude': 129.123215, 'timestamp': 1746608088.9396663}
# Received message: {'car_id': '3235/100000', 'speed': 96.6, 'latitude': 35.013083, 'longitude': 129.123069, 'timestamp': 1746608089.4413447}
# Received message: {'car_id': '3236/100000', 'speed': 97.0, 'latitude': 35.013011, 'longitude': 129.122918, 'timestamp': 1746608089.9443388}
# Received message: {'car_id': '3237/100000', 'speed': 96.7, 'latitude': 35.012933, 'longitude': 129.122777, 'timestamp': 1746608090.445862}
# Received message: {'car_id': '3238/100000', 'speed': 96.3, 'latitude': 35.01286, 'longitude': 129.122629, 'timestamp': 1746608090.9489405}
# Received message: {'car_id': '3239/100000', 'speed': 96.3, 'latitude': 35.01279, 'longitude': 129.122478, 'timestamp': 1746608091.4504225}
# Received message: {'car_id': '3240/100000', 'speed': 96.2, 'latitude': 35.012718, 'longitude': 129.122329, 'timestamp': 1746608091.9534705}
# Received message: {'car_id': '3241/100000', 'speed': 96.2, 'latitude': 35.012643, 'longitude': 129.122184, 'timestamp': 1746608092.4564002}
# Received message: {'car_id': '3242/100000', 'speed': 95.8, 'latitude': 35.012564, 'longitude': 129.122046, 'timestamp': 1746608092.9595802}
# Received message: {'car_id': '3265/100000', 'speed': 96.1, 'latitude': 35.010589, 'longitude': 129.119101, 'timestamp': 1746608104.5196655}
# Received message: {'car_id': '3266/100000', 'speed': 96.2, 'latitude': 35.010491, 'longitude': 129.118993, 'timestamp': 1746608105.0210633}
# Received message: {'car_id': '3267/100000', 'speed': 96.7, 'latitude': 35.010392, 'longitude': 129.118887, 'timestamp': 1746608105.524455}
# Received message: {'car_id': '3268/100000', 'speed': 97.0, 'latitude': 35.010289, 'longitude': 129.118788, 'timestamp': 1746608106.025936}
# Received message: {'car_id': '3269/100000', 'speed': 96.5, 'latitude': 35.010182, 'longitude': 129.1187, 'timestamp': 1746608106.527561}
# Received message: {'car_id': '3270/100000', 'speed': 96.9, 'latitude': 35.010074, 'longitude': 129.118617, 'timestamp': 1746608107.03054}
# Received message: {'car_id': '3271/100000', 'speed': 96.5, 'latitude': 35.009969, 'longitude': 129.118524, 'timestamp': 1746608107.5335937}
# Received message: {'car_id': '3272/100000', 'speed': 96.4, 'latitude': 35.009867, 'longitude': 129.118425, 'timestamp': 1746608108.0349956}
# Received message: {'car_id': '3273/100000', 'speed': 96.4, 'latitude': 35.009766, 'longitude': 129.118323, 'timestamp': 1746608108.538066}
# Received message: {'car_id': '3274/100000', 'speed': 96.9, 'latitude': 35.009664, 'longitude': 129.118223, 'timestamp': 1746608109.0395546}
# Received message: {'car_id': '3275/100000', 'speed': 96.4, 'latitude': 35.009561, 'longitude': 129.118127, 'timestamp': 1746608109.5427105}
# Received message: {'car_id': '3276/100000', 'speed': 96.2, 'latitude': 35.009454, 'longitude': 129.118041, 'timestamp': 1746608110.0457966}
# Received message: {'car_id': '3277/100000', 'speed': 96.1, 'latitude': 35.009348, 'longitude': 129.117952, 'timestamp': 1746608110.5489721}
# Received message: {'car_id': '3278/100000', 'speed': 96.5, 'latitude': 35.009241, 'longitude': 129.117869, 'timestamp': 1746608111.0505943}
# Received message: {'car_id': '3279/100000', 'speed': 96.2, 'latitude': 35.00913, 'longitude': 129.117794, 'timestamp': 1746608111.5534644}
# Received message: {'car_id': '3280/100000', 'speed': 96.7, 'latitude': 35.009022, 'longitude': 129.117712, 'timestamp': 1746608112.054979}
# Received message: {'car_id': '3281/100000', 'speed': 96.4, 'latitude': 35.00891, 'longitude': 129.117644, 'timestamp': 1746608112.55803}
# Received message: {'car_id': '3282/100000', 'speed': 96.3, 'latitude': 35.008801, 'longitude': 129.117563, 'timestamp': 1746608113.061478}
# Received message: {'car_id': '3283/100000', 'speed': 95.9, 'latitude': 35.008689, 'longitude': 129.117496, 'timestamp': 1746608113.5629942}
# Received message: {'car_id': '3284/100000', 'speed': 96.3, 'latitude': 35.008578, 'longitude': 129.117423, 'timestamp': 1746608114.0665822}
# Received message: {'car_id': '3285/100000', 'speed': 96.4, 'latitude': 35.008465, 'longitude': 129.11736, 'timestamp': 1746608114.5696778}
# Received message: {'car_id': '3286/100000', 'speed': 96.7, 'latitude': 35.008351, 'longitude': 129.117299, 'timestamp': 1746608115.0727203}
# Received message: {'car_id': '3310/100000', 'speed': 96.7, 'latitude': 35.005642, 'longitude': 129.11577, 'timestamp': 1746608127.1427057}
# Received message: {'car_id': '3311/100000', 'speed': 96.7, 'latitude': 35.00553, 'longitude': 129.115698, 'timestamp': 1746608127.6457624}
# Received message: {'car_id': '3312/100000', 'speed': 96.9, 'latitude': 35.005422, 'longitude': 129.115612, 'timestamp': 1746608128.1474218}
# Received message: {'car_id': '3313/100000', 'speed': 97.1, 'latitude': 35.005317, 'longitude': 129.115518, 'timestamp': 1746608128.6505156}
# Received message: {'car_id': '3314/100000', 'speed': 97.0, 'latitude': 35.005216, 'longitude': 129.115414, 'timestamp': 1746608129.1536117}
# Received message: {'car_id': '3315/100000', 'speed': 96.9, 'latitude': 35.005113, 'longitude': 129.115316, 'timestamp': 1746608129.6565971}
# Received message: {'car_id': '3316/100000', 'speed': 96.6, 'latitude': 35.005006, 'longitude': 129.115229, 'timestamp': 1746608130.1596787}
# Received message: {'car_id': '3317/100000', 'speed': 96.6, 'latitude': 35.0049, 'longitude': 129.115139, 'timestamp': 1746608130.662956}
# Received message: {'car_id': '3318/100000', 'speed': 96.6, 'latitude': 35.00479, 'longitude': 129.115063, 'timestamp': 1746608131.1661181}
# Received message: {'car_id': '3319/100000', 'speed': 96.2, 'latitude': 35.004678, 'longitude': 129.114995, 'timestamp': 1746608131.6695182}
# Received message: {'car_id': '3320/100000', 'speed': 96.6, 'latitude': 35.004565, 'longitude': 129.114928, 'timestamp': 1746608132.1726139}
# Received message: {'car_id': '3321/100000', 'speed': 96.6, 'latitude': 35.004451, 'longitude': 129.114866, 'timestamp': 1746608132.675553}
# Received message: {'car_id': '3322/100000', 'speed': 96.7, 'latitude': 35.004338, 'longitude': 129.114801, 'timestamp': 1746608133.178672}
# Received message: {'car_id': '3323/100000', 'speed': 96.5, 'latitude': 35.004223, 'longitude': 129.114744, 'timestamp': 1746608133.6816945}
# Received message: {'car_id': '3324/100000', 'speed': 96.1, 'latitude': 35.004108, 'longitude': 129.114691, 'timestamp': 1746608134.1827009}
# Received message: {'car_id': '3325/100000', 'speed': 96.4, 'latitude': 35.00399, 'longitude': 129.11465, 'timestamp': 1746608134.6843395}
# Received message: {'car_id': '3326/100000', 'speed': 96.4, 'latitude': 35.003871, 'longitude': 129.11462, 'timestamp': 1746608135.187533}
# Received message: {'car_id': '3327/100000', 'speed': 96.1, 'latitude': 35.003754, 'longitude': 129.114576, 'timestamp': 1746608135.6885517}
# Received message: {'car_id': '3328/100000', 'speed': 96.1, 'latitude': 35.00364, 'longitude': 129.114519, 'timestamp': 1746608136.1916573}
# Received message: {'car_id': '3329/100000', 'speed': 95.9, 'latitude': 35.003528, 'longitude': 129.114454, 'timestamp': 1746608136.6944935}
# Received message: {'car_id': '3330/100000', 'speed': 95.8, 'latitude': 35.003416, 'longitude': 129.114387, 'timestamp': 1746608137.1956818}
# Received message: {'car_id': '3331/100000', 'speed': 95.6, 'latitude': 35.003307, 'longitude': 129.11431, 'timestamp': 1746608137.6986535}
# Received message: {'car_id': '3332/100000', 'speed': 95.1, 'latitude': 35.003202, 'longitude': 129.114224, 'timestamp': 1746608138.2016962}
# Received message: {'car_id': '3333/100000', 'speed': 95.2, 'latitude': 35.0031, 'longitude': 129.11413, 'timestamp': 1746608138.7048519}
# Received message: {'car_id': '3334/100000', 'speed': 95.7, 'latitude': 35.002995, 'longitude': 129.114042, 'timestamp': 1746608139.2079291}
# Received message: {'car_id': '3335/100000', 'speed': 96.0, 'latitude': 35.002887, 'longitude': 129.113962, 'timestamp': 1746608139.7109747}
# Received message: {'car_id': '3336/100000', 'speed': 96.4, 'latitude': 35.002776, 'longitude': 129.113887, 'timestamp': 1746608140.2139566}
# Received message: {'car_id': '3337/100000', 'speed': 96.1, 'latitude': 35.00267, 'longitude': 129.113801, 'timestamp': 1746608140.7170136}
# Received message: {'car_id': '3338/100000', 'speed': 96.3, 'latitude': 35.002559, 'longitude': 129.113726, 'timestamp': 1746608141.2200754}
# Received message: {'car_id': '3339/100000', 'speed': 96.0, 'latitude': 35.002446, 'longitude': 129.113664, 'timestamp': 1746608141.7217867}
# Received message: {'car_id': '3340/100000', 'speed': 95.8, 'latitude': 35.002334, 'longitude': 129.113599, 'timestamp': 1746608142.2249708}
# Received message: {'car_id': '3341/100000', 'speed': 96.0, 'latitude': 35.002224, 'longitude': 129.113523, 'timestamp': 1746608142.7275767}
# Received message: {'car_id': '3342/100000', 'speed': 95.7, 'latitude': 35.002113, 'longitude': 129.113454, 'timestamp': 1746608143.2306092}
# Received message: {'car_id': '3343/100000', 'speed': 95.2, 'latitude': 35.002005, 'longitude': 129.113379, 'timestamp': 1746608143.733696}
# Received message: {'car_id': '3344/100000', 'speed': 95.2, 'latitude': 35.001894, 'longitude': 129.113309, 'timestamp': 1746608144.2367673}
# Received message: {'car_id': '3345/100000', 'speed': 95.7, 'latitude': 35.001783, 'longitude': 129.113243, 'timestamp': 1746608144.738429}
# Received message: {'car_id': '3346/100000', 'speed': 96.1, 'latitude': 35.00167, 'longitude': 129.113179, 'timestamp': 1746608145.2415452}
# Received message: {'car_id': '3347/100000', 'speed': 96.4, 'latitude': 35.001555, 'longitude': 129.113123, 'timestamp': 1746608145.7446096}
# Received message: {'car_id': '3348/100000', 'speed': 96.3, 'latitude': 35.00144, 'longitude': 129.113065, 'timestamp': 1746608146.247698}
# Received message: {'car_id': '3349/100000', 'speed': 96.2, 'latitude': 35.001324, 'longitude': 129.113019, 'timestamp': 1746608146.7507138}
# Received message: {'car_id': '3350/100000', 'speed': 96.4, 'latitude': 35.001207, 'longitude': 129.112971, 'timestamp': 1746608147.2537067}
# Received message: {'car_id': '3351/100000', 'speed': 96.0, 'latitude': 35.001089, 'longitude': 129.112936, 'timestamp': 1746608147.7568011}
# Received message: {'car_id': '3352/100000', 'speed': 95.5, 'latitude': 35.000973, 'longitude': 129.112896, 'timestamp': 1746608148.259893}
# Received message: {'car_id': '3353/100000', 'speed': 95.1, 'latitude': 35.000855, 'longitude': 129.112866, 'timestamp': 1746608148.7629368}
# Received message: {'car_id': '3354/100000', 'speed': 95.0, 'latitude': 35.000738, 'longitude': 129.11284, 'timestamp': 1746608149.2665668}
# Received message: {'car_id': '3377/100000', 'speed': 95.2, 'latitude': 34.998045, 'longitude': 129.112104, 'timestamp': 1746608160.8311257}
# Received message: {'car_id': '3378/100000', 'speed': 94.9, 'latitude': 34.997927, 'longitude': 129.112105, 'timestamp': 1746608161.3343608}
# Received message: {'car_id': '3379/100000', 'speed': 95.3, 'latitude': 34.997808, 'longitude': 129.112115, 'timestamp': 1746608161.837067}
# Received message: {'car_id': '3380/100000', 'speed': 95.6, 'latitude': 34.997688, 'longitude': 129.112123, 'timestamp': 1746608162.3401475}
# Received message: {'car_id': '3381/100000', 'speed': 95.3, 'latitude': 34.997569, 'longitude': 129.112125, 'timestamp': 1746608162.8432212}
# Received message: {'car_id': '3382/100000', 'speed': 95.1, 'latitude': 34.99745, 'longitude': 129.112116, 'timestamp': 1746608163.3462925}
# Received message: {'car_id': '3383/100000', 'speed': 95.4, 'latitude': 34.997331, 'longitude': 129.112095, 'timestamp': 1746608163.8492649}
# Received message: {'car_id': '3384/100000', 'speed': 95.8, 'latitude': 34.997214, 'longitude': 129.11206, 'timestamp': 1746608164.3521967}
# Received message: {'car_id': '3385/100000', 'speed': 96.1, 'latitude': 34.997097, 'longitude': 129.112018, 'timestamp': 1746608164.8552494}
# Received message: {'car_id': '3386/100000', 'speed': 96.0, 'latitude': 34.996978, 'longitude': 129.111987, 'timestamp': 1746608165.35843}
# Received message: {'car_id': '3387/100000', 'speed': 96.3, 'latitude': 34.996861, 'longitude': 129.111944, 'timestamp': 1746608165.8619485}
# Received message: {'car_id': '3388/100000', 'speed': 96.0, 'latitude': 34.996744, 'longitude': 129.111905, 'timestamp': 1746608166.3635736}
# Received message: {'car_id': '3389/100000', 'speed': 96.2, 'latitude': 34.996626, 'longitude': 129.111865, 'timestamp': 1746608166.866929}
# Received message: {'car_id': '3390/100000', 'speed': 96.2, 'latitude': 34.99651, 'longitude': 129.111818, 'timestamp': 1746608167.3679705}
# Received message: {'car_id': '3391/100000', 'speed': 96.3, 'latitude': 34.996396, 'longitude': 129.111758, 'timestamp': 1746608167.8709097}
# Received message: {'car_id': '3392/100000', 'speed': 96.7, 'latitude': 34.996283, 'longitude': 129.11169, 'timestamp': 1746608168.373905}
# Received message: {'car_id': '3393/100000', 'speed': 96.5, 'latitude': 34.996168, 'longitude': 129.111633, 'timestamp': 1746608168.8769667}
# Received message: {'car_id': '3394/100000', 'speed': 96.8, 'latitude': 34.996054, 'longitude': 129.111568, 'timestamp': 1746608169.3784564}
# Received message: {'car_id': '3395/100000', 'speed': 96.9, 'latitude': 34.995942, 'longitude': 129.111498, 'timestamp': 1746608169.8799868}
# Received message: {'car_id': '3396/100000', 'speed': 97.0, 'latitude': 34.995828, 'longitude': 129.111432, 'timestamp': 1746608170.3830502}
# Received message: {'car_id': '3397/100000', 'speed': 97.0, 'latitude': 34.995716, 'longitude': 129.111363, 'timestamp': 1746608170.8845496}
# Received message: {'car_id': '3398/100000', 'speed': 97.4, 'latitude': 34.9956, 'longitude': 129.111305, 'timestamp': 1746608171.387667}
# Received message: {'car_id': '3399/100000', 'speed': 97.8, 'latitude': 34.995486, 'longitude': 129.111234, 'timestamp': 1746608171.8892016}
# Received message: {'car_id': '3400/100000', 'speed': 97.6, 'latitude': 34.995377, 'longitude': 129.111149, 'timestamp': 1746608172.390922}
# Received message: {'car_id': '3401/100000', 'speed': 97.2, 'latitude': 34.995269, 'longitude': 129.111063, 'timestamp': 1746608172.8939888}
# Received message: {'car_id': '3402/100000', 'speed': 97.0, 'latitude': 34.995162, 'longitude': 129.110977, 'timestamp': 1746608173.3969347}
# Received message: {'car_id': '3403/100000', 'speed': 96.6, 'latitude': 34.995058, 'longitude': 129.110882, 'timestamp': 1746608173.899985}
# Received message: {'car_id': '3404/100000', 'speed': 96.9, 'latitude': 34.994958, 'longitude': 129.110777, 'timestamp': 1746608174.4027884}
# Received message: {'car_id': '3405/100000', 'speed': 96.8, 'latitude': 34.994854, 'longitude': 129.110679, 'timestamp': 1746608174.9056976}
# Received message: {'car_id': '3406/100000', 'speed': 96.6, 'latitude': 34.994755, 'longitude': 129.110574, 'timestamp': 1746608175.4084637}
# Received message: {'car_id': '3407/100000', 'speed': 96.4, 'latitude': 34.99466, 'longitude': 129.11046, 'timestamp': 1746608175.9113874}
# Received message: {'car_id': '3408/100000', 'speed': 96.5, 'latitude': 34.994564, 'longitude': 129.110346, 'timestamp': 1746608176.4142141}
# Received message: {'car_id': '3409/100000', 'speed': 96.3, 'latitude': 34.994465, 'longitude': 129.110241, 'timestamp': 1746608176.9169571}
# Received message: {'car_id': '3410/100000', 'speed': 96.5, 'latitude': 34.994371, 'longitude': 129.110124, 'timestamp': 1746608177.418471}
# Received message: {'car_id': '3411/100000', 'speed': 96.3, 'latitude': 34.994271, 'longitude': 129.11002, 'timestamp': 1746608177.920926}
# Received message: {'car_id': '3412/100000', 'speed': 96.2, 'latitude': 34.994176, 'longitude': 129.109906, 'timestamp': 1746608178.423047}
# Received message: {'car_id': '3413/100000', 'speed': 96.4, 'latitude': 34.994085, 'longitude': 129.109785, 'timestamp': 1746608178.9241185}
# Received message: {'car_id': '3414/100000', 'speed': 96.8, 'latitude': 34.993997, 'longitude': 129.109655, 'timestamp': 1746608179.427167}
# Received message: {'car_id': '3415/100000', 'speed': 96.9, 'latitude': 34.99391, 'longitude': 129.109526, 'timestamp': 1746608179.9301274}
# Received message: {'car_id': '3416/100000', 'speed': 97.3, 'latitude': 34.993821, 'longitude': 129.109398, 'timestamp': 1746608180.4317734}
# Received message: {'car_id': '3417/100000', 'speed': 97.3, 'latitude': 34.993741, 'longitude': 129.109257, 'timestamp': 1746608180.9347682}
# Received message: {'car_id': '3418/100000', 'speed': 97.2, 'latitude': 34.993658, 'longitude': 129.10912, 'timestamp': 1746608181.437891}
# Received message: {'car_id': '3419/100000', 'speed': 96.7, 'latitude': 34.993569, 'longitude': 129.108993, 'timestamp': 1746608181.9408476}
# Received message: {'car_id': '3420/100000', 'speed': 97.1, 'latitude': 34.993488, 'longitude': 129.108855, 'timestamp': 1746608182.4442213}
# Received message: {'car_id': '3421/100000', 'speed': 96.7, 'latitude': 34.993405, 'longitude': 129.108718, 'timestamp': 1746608182.9469566}
# Received message: {'car_id': '3422/100000', 'speed': 96.8, 'latitude': 34.993329, 'longitude': 129.108573, 'timestamp': 1746608183.4500442}
# Received message: {'car_id': '3423/100000', 'speed': 96.7, 'latitude': 34.99326, 'longitude': 129.10842, 'timestamp': 1746608183.9530945}
# Received message: {'car_id': '3424/100000', 'speed': 97.2, 'latitude': 34.993188, 'longitude': 129.108269, 'timestamp': 1746608184.456593}
# Received message: {'car_id': '3425/100000', 'speed': 97.4, 'latitude': 34.993122, 'longitude': 129.108112, 'timestamp': 1746608184.9595847}
# Received message: {'car_id': '3426/100000', 'speed': 97.3, 'latitude': 34.993058, 'longitude': 129.107952, 'timestamp': 1746608185.4626756}
# Received message: {'car_id': '3427/100000', 'speed': 97.4, 'latitude': 34.99299, 'longitude': 129.107796, 'timestamp': 1746608185.9655857}
# Received message: {'car_id': '3428/100000', 'speed': 97.4, 'latitude': 34.99293, 'longitude': 129.107632, 'timestamp': 1746608186.46725}
# Received message: {'car_id': '3429/100000', 'speed': 97.1, 'latitude': 34.992866, 'longitude': 129.107474, 'timestamp': 1746608186.970347}
# Received message: {'car_id': '3430/100000', 'speed': 97.4, 'latitude': 34.992796, 'longitude': 129.10732, 'timestamp': 1746608187.4734206}
# Received message: {'car_id': '3431/100000', 'speed': 97.7, 'latitude': 34.992726, 'longitude': 129.107166, 'timestamp': 1746608187.9764328}
# Received message: {'car_id': '3432/100000', 'speed': 98.2, 'latitude': 34.992656, 'longitude': 129.10701, 'timestamp': 1746608188.479498}
# Received message: {'car_id': '3433/100000', 'speed': 98.1, 'latitude': 34.992593, 'longitude': 129.106848, 'timestamp': 1746608188.982669}
# Received message: {'car_id': '3434/100000', 'speed': 97.9, 'latitude': 34.992527, 'longitude': 129.106689, 'timestamp': 1746608189.4857562}
# Received message: {'car_id': '3435/100000', 'speed': 98.3, 'latitude': 34.992468, 'longitude': 129.106523, 'timestamp': 1746608189.9889283}
# Received message: {'car_id': '3436/100000', 'speed': 97.9, 'latitude': 34.992416, 'longitude': 129.106352, 'timestamp': 1746608190.4919634}
# Received message: {'car_id': '3437/100000', 'speed': 98.1, 'latitude': 34.992367, 'longitude': 129.106179, 'timestamp': 1746608190.9949622}
# Received message: {'car_id': '3438/100000', 'speed': 98.2, 'latitude': 34.99232, 'longitude': 129.106004, 'timestamp': 1746608191.4981449}
# Received message: {'car_id': '3439/100000', 'speed': 98.1, 'latitude': 34.992269, 'longitude': 129.105832, 'timestamp': 1746608191.9995155}
# Received message: {'car_id': '3440/100000', 'speed': 97.6, 'latitude': 34.992224, 'longitude': 129.105657, 'timestamp': 1746608192.502549}
# Received message: {'car_id': '3441/100000', 'speed': 97.5, 'latitude': 34.992181, 'longitude': 129.105482, 'timestamp': 1746608193.0040762}
# Received message: {'car_id': '3442/100000', 'speed': 97.1, 'latitude': 34.992142, 'longitude': 129.105304, 'timestamp': 1746608193.5071738}
# Received message: {'car_id': '3443/100000', 'speed': 96.7, 'latitude': 34.9921, 'longitude': 129.10513, 'timestamp': 1746608194.0102484}
# Received message: {'car_id': '3444/100000', 'speed': 96.8, 'latitude': 34.992056, 'longitude': 129.104956, 'timestamp': 1746608194.511968}
# Received message: {'car_id': '3445/100000', 'speed': 96.7, 'latitude': 34.992008, 'longitude': 129.104785, 'timestamp': 1746608195.0153232}
# Received message: {'car_id': '3446/100000', 'speed': 96.6, 'latitude': 34.991965, 'longitude': 129.104611, 'timestamp': 1746608195.5183825}
# Received message: {'car_id': '3447/100000', 'speed': 96.6, 'latitude': 34.991923, 'longitude': 129.104437, 'timestamp': 1746608196.0210268}
# Received message: {'car_id': '3448/100000', 'speed': 96.3, 'latitude': 34.991882, 'longitude': 129.104262, 'timestamp': 1746608196.5240254}
# Received message: {'car_id': '3449/100000', 'speed': 96.4, 'latitude': 34.99184, 'longitude': 129.104088, 'timestamp': 1746608197.025257}
# Received message: {'car_id': '3450/100000', 'speed': 96.0, 'latitude': 34.991792, 'longitude': 129.103919, 'timestamp': 1746608197.528115}
# Received message: {'car_id': '3451/100000', 'speed': 95.8, 'latitude': 34.991741, 'longitude': 129.103751, 'timestamp': 1746608198.0294821}
# Received message: {'car_id': '3452/100000', 'speed': 96.2, 'latitude': 34.991695, 'longitude': 129.10358, 'timestamp': 1746608198.5310557}
# Received message: {'car_id': '3453/100000', 'speed': 95.9, 'latitude': 34.991641, 'longitude': 129.103415, 'timestamp': 1746608199.032546}
# Received message: {'car_id': '3454/100000', 'speed': 96.1, 'latitude': 34.991594, 'longitude': 129.103245, 'timestamp': 1746608199.5351517}
# Received message: {'car_id': '3455/100000', 'speed': 96.3, 'latitude': 34.991548, 'longitude': 129.103073, 'timestamp': 1746608200.0366735}
# Received message: {'car_id': '3456/100000', 'speed': 95.8, 'latitude': 34.991504, 'longitude': 129.102901, 'timestamp': 1746608200.5383358}
# Received message: {'car_id': '3457/100000', 'speed': 96.0, 'latitude': 34.991469, 'longitude': 129.102725, 'timestamp': 1746608201.041423}
# Received message: {'car_id': '3458/100000', 'speed': 95.7, 'latitude': 34.991435, 'longitude': 129.102548, 'timestamp': 1746608201.5446758}
# Received message: {'car_id': '3459/100000', 'speed': 95.5, 'latitude': 34.991405, 'longitude': 129.10237, 'timestamp': 1746608202.046376}
# Received message: {'car_id': '3460/100000', 'speed': 95.4, 'latitude': 34.991366, 'longitude': 129.102196, 'timestamp': 1746608202.5494528}
# Received message: {'car_id': '3461/100000', 'speed': 95.0, 'latitude': 34.99132, 'longitude': 129.102027, 'timestamp': 1746608203.0522046}
# Received message: {'car_id': '3462/100000', 'speed': 94.8, 'latitude': 34.991274, 'longitude': 129.101859, 'timestamp': 1746608203.5551505}
# Received message: {'car_id': '3463/100000', 'speed': 95.0, 'latitude': 34.991223, 'longitude': 129.101694, 'timestamp': 1746608204.0581362}
# Received message: {'car_id': '3464/100000', 'speed': 95.0, 'latitude': 34.991177, 'longitude': 129.101525, 'timestamp': 1746608204.561218}
# Received message: {'car_id': '3465/100000', 'speed': 95.3, 'latitude': 34.991136, 'longitude': 129.101352, 'timestamp': 1746608205.0642579}
# Received message: {'car_id': '3466/100000', 'speed': 95.2, 'latitude': 34.991098, 'longitude': 129.101178, 'timestamp': 1746608205.567299}
# Received message: {'car_id': '3467/100000', 'speed': 95.4, 'latitude': 34.991065, 'longitude': 129.101002, 'timestamp': 1746608206.0704234}
# Received message: {'car_id': '3468/100000', 'speed': 95.7, 'latitude': 34.99104, 'longitude': 129.100821, 'timestamp': 1746608206.5720825}
# Received message: {'car_id': '3469/100000', 'speed': 95.7, 'latitude': 34.991013, 'longitude': 129.100642, 'timestamp': 1746608207.0737703}
# Received message: {'car_id': '3470/100000', 'speed': 95.9, 'latitude': 34.990987, 'longitude': 129.100461, 'timestamp': 1746608207.5754378}
# Received message: {'car_id': '3471/100000', 'speed': 95.7, 'latitude': 34.990952, 'longitude': 129.100285, 'timestamp': 1746608208.078459}
# Received message: {'car_id': '3472/100000', 'speed': 95.9, 'latitude': 34.990913, 'longitude': 129.10011, 'timestamp': 1746608208.581442}
# Received message: {'car_id': '3473/100000', 'speed': 96.1, 'latitude': 34.990866, 'longitude': 129.09994, 'timestamp': 1746608209.0845327}
# Received message: {'car_id': '3474/100000', 'speed': 96.2, 'latitude': 34.990825, 'longitude': 129.099766, 'timestamp': 1746608209.5869708}
# Received message: {'car_id': '3475/100000', 'speed': 96.5, 'latitude': 34.990776, 'longitude': 129.099595, 'timestamp': 1746608210.0881135}
# Received message: {'car_id': '3476/100000', 'speed': 96.2, 'latitude': 34.990738, 'longitude': 129.09942, 'timestamp': 1746608210.5911932}
# ...
# Received message: {'car_id': '5009/100000', 'speed': 93.2, 'latitude': 35.067385, 'longitude': 129.013352, 'timestamp': 1746608981.243214}
# Received message: {'car_id': '5010/100000', 'speed': 93.2, 'latitude': 35.0675, 'longitude': 129.01332, 'timestamp': 1746608981.7465801}
# Received message: {'car_id': '5011/100000', 'speed': 93.3, 'latitude': 35.067614, 'longitude': 129.013285, 'timestamp': 1746608982.2496655}
# Received message: {'car_id': '5012/100000', 'speed': 92.9, 'latitude': 35.067729, 'longitude': 129.013252, 'timestamp': 1746608982.7527401}
# Received message: {'car_id': '5013/100000', 'speed': 93.0, 'latitude': 35.067842, 'longitude': 129.01321, 'timestamp': 1746608983.25579}
# Received message: {'car_id': '5014/100000', 'speed': 92.5, 'latitude': 35.067955, 'longitude': 129.013174, 'timestamp': 1746608983.7587817}
# Received message: {'car_id': '5015/100000', 'speed': 92.2, 'latitude': 35.068068, 'longitude': 129.013141, 'timestamp': 1746608984.2617152}
# Received message: {'car_id': '5016/100000', 'speed': 92.7, 'latitude': 35.06818, 'longitude': 129.013094, 'timestamp': 1746608984.76466}
# Received message: {'car_id': '5017/100000', 'speed': 92.4, 'latitude': 35.068293, 'longitude': 129.013053, 'timestamp': 1746608985.267722}
# Received message: {'car_id': '5018/100000', 'speed': 92.7, 'latitude': 35.068405, 'longitude': 129.01301, 'timestamp': 1746608985.770696}
# Received message: {'car_id': '5019/100000', 'speed': 93.0, 'latitude': 35.068518, 'longitude': 129.012962, 'timestamp': 1746608986.2737286}
# Received message: {'car_id': '5020/100000', 'speed': 92.8, 'latitude': 35.068631, 'longitude': 129.012922, 'timestamp': 1746608986.7767081}
# Received message: {'car_id': '5021/100000', 'speed': 92.9, 'latitude': 35.068746, 'longitude': 129.012895, 'timestamp': 1746608987.2797291}
# Received message: {'car_id': '5022/100000', 'speed': 92.4, 'latitude': 35.06886, 'longitude': 129.012873, 'timestamp': 1746608987.782654}
# Received message: {'car_id': '5023/100000', 'speed': 92.5, 'latitude': 35.068974, 'longitude': 129.012841, 'timestamp': 1746608988.285728}
# Received message: {'car_id': '5024/100000', 'speed': 92.7, 'latitude': 35.069087, 'longitude': 129.012798, 'timestamp': 1746608988.7887106}
# Received message: {'car_id': '5025/100000', 'speed': 92.5, 'latitude': 35.069199, 'longitude': 129.012752, 'timestamp': 1746608989.2918053}
# Received message: {'car_id': '5026/100000', 'speed': 92.1, 'latitude': 35.069311, 'longitude': 129.012714, 'timestamp': 1746608989.794573}
# Received message: {'car_id': '5027/100000', 'speed': 92.3, 'latitude': 35.069425, 'longitude': 129.012687, 'timestamp': 1746608990.2976766}
# Received message: {'car_id': '5028/100000', 'speed': 92.3, 'latitude': 35.069538, 'longitude': 129.012646, 'timestamp': 1746608990.7993722}
# Received message: {'car_id': '5029/100000', 'speed': 92.7, 'latitude': 35.06965, 'longitude': 129.012601, 'timestamp': 1746608991.302665}
# Received message: {'car_id': '5030/100000', 'speed': 92.4, 'latitude': 35.069764, 'longitude': 129.012568, 'timestamp': 1746608991.8042278}
# Received message: {'car_id': '5031/100000', 'speed': 92.7, 'latitude': 35.069879, 'longitude': 129.012548, 'timestamp': 1746608992.3070493}
# Received message: {'car_id': '5032/100000', 'speed': 92.7, 'latitude': 35.069993, 'longitude': 129.012517, 'timestamp': 1746608992.8093672}
# Received message: {'car_id': '5033/100000', 'speed': 92.2, 'latitude': 35.070106, 'longitude': 129.012481, 'timestamp': 1746608993.3119023}
# Received message: {'car_id': '5034/100000', 'speed': 92.7, 'latitude': 35.070219, 'longitude': 129.012439, 'timestamp': 1746608993.8131542}
# Received message: {'car_id': '5035/100000', 'speed': 92.7, 'latitude': 35.070329, 'longitude': 129.012383, 'timestamp': 1746608994.3160338}
# Received message: {'car_id': '5036/100000', 'speed': 92.3, 'latitude': 35.070441, 'longitude': 129.012336, 'timestamp': 1746608994.8191657}
# Received message: {'car_id': '5037/100000', 'speed': 92.5, 'latitude': 35.070553, 'longitude': 129.012295, 'timestamp': 1746608995.3220878}
# Received message: {'car_id': '5038/100000', 'speed': 92.6, 'latitude': 35.070667, 'longitude': 129.012259, 'timestamp': 1746608995.825155}
# Received message: {'car_id': '5039/100000', 'speed': 92.6, 'latitude': 35.070779, 'longitude': 129.012215, 'timestamp': 1746608996.3281739}
# Received message: {'car_id': '5040/100000', 'speed': 93.0, 'latitude': 35.07089, 'longitude': 129.01216, 'timestamp': 1746608996.831245}
# Received message: {'car_id': '5041/100000', 'speed': 92.9, 'latitude': 35.071002, 'longitude': 129.012114, 'timestamp': 1746608997.3341703}
# Received message: {'car_id': '5042/100000', 'speed': 93.0, 'latitude': 35.071114, 'longitude': 129.012062, 'timestamp': 1746608997.8378925}
# Received message: {'car_id': '5043/100000', 'speed': 93.4, 'latitude': 35.071227, 'longitude': 129.012016, 'timestamp': 1746608998.3395362}
# Received message: {'car_id': '5088/100000', 'speed': 97.7, 'latitude': 35.075874, 'longitude': 129.008024, 'timestamp': 1746609020.95915}
# Received message: {'car_id': '5089/100000', 'speed': 97.3, 'latitude': 35.075978, 'longitude': 129.007928, 'timestamp': 1746609021.4620388}
# Received message: {'car_id': '5090/100000', 'speed': 97.1, 'latitude': 35.076078, 'longitude': 129.007822, 'timestamp': 1746609021.9650922}
# Received message: {'car_id': '5091/100000', 'speed': 97.2, 'latitude': 35.076183, 'longitude': 129.007728, 'timestamp': 1746609022.4681695}
# Received message: {'car_id': '5092/100000', 'speed': 97.4, 'latitude': 35.076292, 'longitude': 129.007644, 'timestamp': 1746609022.9712007}
# Received message: {'car_id': '5093/100000', 'speed': 96.9, 'latitude': 35.076404, 'longitude': 129.007571, 'timestamp': 1746609023.4741492}
# Received message: {'car_id': '5094/100000', 'speed': 96.4, 'latitude': 35.076515, 'longitude': 129.007497, 'timestamp': 1746609023.9771435}
# Received message: {'car_id': '5095/100000', 'speed': 96.3, 'latitude': 35.076624, 'longitude': 129.007419, 'timestamp': 1746609024.4788926}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#       4 consumer = KafkaConsumer(
#       5     topic_name,
#       6     bootstrap_servers = bootstrap_servers,
#    (...)
#      10     value_deserializer=lambda x: json.loads(x.decode("utf-8"))
#      11 )
#      13 print("데이터 가져오는중")
# ---> 15 for message in consumer:
#      16     print(f"Received message: {message.value}")
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:693, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     691 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     692 while not self._closed:
# --> 693     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     694     if records:
#     695         return records
#
# File ~/.local/lib/python3.10/site-packages/kafka/consumer/group.py:736, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     733 if records:
#     734     return records
# --> 736 self._client.poll(timeout_ms=inner_timeout_ms(self._coordinator.time_to_next_poll() * 1000))
#     737 # after the long poll, we should check whether the group needs to rebalance
#     738 # prior to returning data so that the group can stabilize faster
#     739 if self._coordinator.need_rejoin():
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:684, in KafkaClient.poll(self, timeout_ms, future)
#     677         timeout = min(
#     678             user_timeout_ms,
#     679             metadata_timeout_ms,
#     680             idle_connection_timeout_ms,
#     681             request_timeout_ms)
#     682         timeout = max(0, timeout)  # avoid negative timeouts
# --> 684     self._poll(timeout / 1000)
#     686 # called without the lock to avoid deadlock potential
#     687 # if handlers need to acquire locks
#     688 responses.extend(self._fire_pending_completed_requests())
#
# File ~/.local/lib/python3.10/site-packages/kafka/client_async.py:727, in KafkaClient._poll(self, timeout)
#     724 self._register_send_sockets()
#     726 start_select = time.time()
# --> 727 ready = self._selector.select(timeout)
#     728 end_select = time.time()
#     729 if self._sensors:
#
# File /usr/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %%
bootstrap_servers = "mydb.iptime.org:9092"
topic_name = "smartcar-data"
out_file = 'smartcar_100.json'

consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers = bootstrap_servers,
    auto_offset_reset = "latest", 
    enable_auto_commit = True,
    value_deserializer=lambda x: json.loads(x.decode("utf-8"))
)

print("데이터 가져오는중")

buffer = []
for message in consumer:
    buffer.append(message.value)
    if len(buffer) == 100:
        break

with open(out_file, 'w', encoding='utf-8') as f:
    for item in buffer:
        json.dump(item, f)
        f.write('\n')

print(f"✅ 메시지 {len(buffer)}개 저장 완료: {out_file}")
# Out:
# 데이터 가져오는중
# ✅ 메시지 100개 저장 완료: smartcar_100.json

# %%
from kafka import KafkaConsumer
import json
import time
from datetime import datetime
import subprocess
import os
import traceback

bootstrap_servers = "mydb.iptime.org:9092"
topic_name = "smartcar-data"
save_interval_sec = 12 * 60 * 60  # 12시간
hdfs_dir = "/user/hadoop/smartcar-data"
local_dir = "/tmp/kafka_buffer"

# 로컬 저장 경로 생성
os.makedirs(local_dir, exist_ok=True)

while True:
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f'smartcar_100_{timestamp}.json'
    local_path = os.path.join(local_dir, filename)
    buffer = []

    print(f"[{timestamp}] Kafka에서 메시지 100개 수집 시작...")

    try:
        consumer = KafkaConsumer(
            topic_name,
            bootstrap_servers=bootstrap_servers,
            auto_offset_reset="latest",
            enable_auto_commit=True,
            value_deserializer=lambda x: json.loads(x.decode("utf-8"))
        )

        for message in consumer:
            buffer.append(message.value)
            if len(buffer) == 100:
                break

    except Exception as e:
        print(f"[!] Kafka 소비 중 오류 발생: {e}")
        traceback.print_exc()

    finally:
        if buffer:
            # 로컬 파일 저장
            with open(local_path, 'w', encoding='utf-8') as f:
                for item in buffer:
                    json.dump(item, f)
                    f.write('\n')

            print(f"[✓] 메시지 {len(buffer)}개 저장 완료: {local_path}")

            # HDFS 디렉토리 생성 (있으면 생략됨)
            subprocess.run(['hdfs', 'dfs', '-mkdir', '-p', hdfs_dir], check=False)

            # HDFS로 업로드
            try:
                subprocess.run(['hdfs', 'dfs', '-put', local_path, hdfs_dir], check=True)
                print(f"[→] HDFS 적재 완료: {hdfs_dir}/{filename}")
                os.remove(local_path)
            except subprocess.CalledProcessError as e:
                print(f"[!] HDFS 업로드 실패: {e}")
        else:
            print("[!] 저장할 메시지가 없어 파일 생성 및 HDFS 업로드 생략됨")

    print(f"[⏳] 12시간 대기...\n")
    time.sleep(save_interval_sec)
