# %% [markdown]
# # 연령별 인구 분포 비교 분석
# - 행정안전부 주민등록 인구 통계
# - 행정동별 연령별 인구현황

# %%
# !pip install seaborn

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import pandas as pd
import numpy as np
import seaborn as sns

from hdfs import InsecureClient

# %%
from matplotlib import rc

plt.rc('font', family="NanumBarunGothic")
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
hdfs = InsecureClient("http://namenode:9870", user="hadoop")
paths = ["200812_201312_연령별인구현황_연간.csv", "201412_201912_연령별인구현황_연간.csv", "202012_202412_연령별인구현황_연간.csv"]
datas = []
for path in paths:
    with hdfs.read(path, encoding="EUC-KR") as reader:
        datas.append(pd.read_csv(reader))
mdata = pd.merge(datas[0], datas[1], on="행정구역", how="left")
data = pd.merge(mdata, datas[2], on="행정구역", how="left")
data
# Out:
#                      행정구역 2008년_계_총인구수 2008년_계_연령구간인구수 2008년_계_0~9세  \
# 0        전국  (0000000000)   49,540,367      49,540,367    5,096,863
# 1     서울특별시  (1100000000)   10,200,827      10,200,827      930,515
# 2     부산광역시  (2600000000)    3,564,577       3,564,577      295,585
# 3     대구광역시  (2700000000)    2,492,724       2,492,724      243,689
# 4     인천광역시  (2800000000)    2,692,696       2,692,696      282,010
# 5     광주광역시  (2900000000)    1,422,702       1,422,702      165,726
# 6     대전광역시  (3000000000)    1,480,895       1,480,895      165,185
# 7     울산광역시  (3100000000)    1,112,407       1,112,407      123,828
# 8   세종특별자치시  (3600000000)            0               0            0
# 9       경기도  (4100000000)   11,292,264      11,292,264    1,329,090
# 10      강원도  (4200000000)    1,508,575       1,508,575      148,237
# 11     충청북도  (4300000000)    1,519,587       1,519,587      158,447
# 12     충청남도  (4400000000)    2,018,537       2,018,537      212,862
# 13     전라북도  (4500000000)    1,855,772       1,855,772      187,075
# 14     전라남도  (4600000000)    1,919,000       1,919,000      185,983
# 15     경상북도  (4700000000)    2,673,931       2,673,931      255,206
# 16     경상남도  (4800000000)    3,225,255       3,225,255      346,853
# 17  제주특별자치도  (5000000000)      560,618         560,618       66,572
#
#    2008년_계_10~19세 2008년_계_20~29세 2008년_계_30~39세 2008년_계_40~49세 2008년_계_50~59세  \
# 0       6,824,922      7,225,638      8,470,294      8,671,848      6,140,573
# 1       1,273,921      1,701,253      1,888,662      1,721,870      1,341,904
# 2         465,555        547,510        549,690        626,029        541,589
# 3         367,756        363,215        407,995        456,905        321,346
# 4         395,667        402,627        468,951        511,496        320,145
# 5         228,874        215,825        243,262        241,756        155,911
# 6         223,036        226,246        259,751        261,080        174,724
# 7         177,287        160,327        192,904        218,035        135,463
# 8               0              0              0              0              0
# 9       1,634,134      1,587,704      2,118,019      2,087,212      1,229,523
# 10        198,539        196,588        225,353        258,752        198,190
# 11        211,999        210,942        238,781        257,980        186,114
# 12        262,791        273,062        316,376        325,925        244,763
# 13        258,021        245,069        272,978        297,898        233,316
# 14        252,258        233,155        260,907        303,468        242,694
# 15        338,850        356,316        401,356        443,641        353,577
# 16        454,277        432,445        533,583        565,042        397,813
# 17         81,957         73,354         91,726         94,759         63,501
#
#    2008년_계_60~69세  ... 2024년_여_10~19세 2024년_여_20~29세 2024년_여_30~39세  \
# 0       3,964,796  ...      2,245,507      2,855,132      3,166,585
# 1         827,725  ...        352,043        692,450        720,478
# 2         327,651  ...        127,955        175,150        188,127
# 3         192,853  ...        103,130        127,260        131,690
# 4         178,327  ...        132,857        169,872        201,668
# 5          98,980  ...         70,457         87,080         83,546
# 6          97,456  ...         65,758         92,510         89,525
# 7          63,038  ...         52,550         49,913         61,638
# 8               0  ...         25,969         18,201         29,798
# 9         737,590  ...        644,297        774,543        909,829
# 10        151,034  ...              0              0              0
# 11        131,196  ...         69,310         77,788         85,178
# 12        186,786  ...         97,599         98,109        114,382
# 13        182,817  ...              0              0              0
# 14        219,728  ...         76,182         74,519         79,651
# 15        263,737  ...        102,956        100,482        115,611
# 16        258,931  ...        151,435        133,107        161,437
# 17         46,947  ...         34,028         32,633         38,100
#
#    2024년_여_40~49세 2024년_여_50~59세 2024년_여_60~69세 2024년_여_70~79세 2024년_여_80~89세  \
# 0       3,796,703      4,315,099      3,968,224      2,254,795      1,326,374
# 1         700,244        755,144        698,464        423,979        210,875
# 2         233,041        274,368        297,863        184,530         92,007
# 3         173,617        214,102        196,231        114,083         63,905
# 4         230,963        259,061        233,050        113,641         62,357
# 5         109,984        122,831         99,320         57,591         30,963
# 6         106,590        122,250        106,338         57,153         31,288
# 7          83,718        101,267         86,836         39,799         18,526
# 8          39,218         27,332         19,457          9,276          5,336
# 9       1,084,852      1,170,670        957,531        484,298        273,431
# 10              0              0              0              0              0
# 11        108,037        132,800        130,168         71,638         48,905
# 12        148,832        165,521        164,043         98,938         71,172
# 13              0              0              0              0              0
# 14        109,608        142,041        150,979        104,464         82,391
# 15        164,827        212,556        226,185        140,665         99,327
# 16        238,017        285,869        270,105        151,651         95,952
# 17         52,038         57,629         48,431         26,866         17,471
#
#    2024년_여_90~99세 2024년_여_100세 이상
# 0         252,368           7,052
# 1          35,979           1,150
# 2          14,561             368
# 3          10,606             223
# 4          12,706             411
# 5           5,822             156
# 6           5,878             178
# 7           3,228              76
# 8           1,300              35
# 9          52,690           1,514
# 10              0               0
# 11          9,648             239
# 12         15,589             412
# 13              0               0
# 14         16,523             468
# 15         19,585             492
# 16         18,845             384
# 17          4,419             217
#
# [18 rows x 664 columns]

# %%
data = data[data.columns[data.columns.str.contains("행정구역|년_남_|년_여_")]]
data = data[data.columns[~data.columns.str.contains("_총인구수|_연령구간인구수")]] # 물결 '~' 표시는 반대값
data
# Out:
#                      행정구역 2008년_남_0~9세 2008년_남_10~19세 2008년_남_20~29세  \
# 0        전국  (0000000000)    2,647,788      3,608,254      3,727,944
# 1     서울특별시  (1100000000)      480,828        669,914        844,653
# 2     부산광역시  (2600000000)      153,939        250,231        282,949
# 3     대구광역시  (2700000000)      128,282        201,741        190,798
# 4     인천광역시  (2800000000)      146,064        206,337        207,510
# 5     광주광역시  (2900000000)       86,287        119,515        109,374
# 6     대전광역시  (3000000000)       85,737        118,337        115,894
# 7     울산광역시  (3100000000)       65,341         96,462         86,015
# 8   세종특별자치시  (3600000000)            0              0              0
# 9       경기도  (4100000000)      687,066        853,402        808,244
# 10      강원도  (4200000000)       77,203        104,323        106,622
# 11     충청북도  (4300000000)       82,393        112,343        111,748
# 12     충청남도  (4400000000)      110,320        138,084        146,137
# 13     전라북도  (4500000000)       96,936        134,687        130,880
# 14     전라남도  (4600000000)       96,463        131,896        126,930
# 15     경상북도  (4700000000)      134,196        183,882        191,522
# 16     경상남도  (4800000000)      181,868        243,981        230,715
# 17  제주특별자치도  (5000000000)       34,865         43,119         37,953
#
#    2008년_남_30~39세 2008년_남_40~49세 2008년_남_50~59세 2008년_남_60~69세 2008년_남_70~79세  \
# 0       4,320,946      4,410,221      3,078,799      1,869,267        925,456
# 1         964,702        852,139        650,194        401,879        159,039
# 2         278,418        305,539        266,497        158,167         64,355
# 3         202,082        225,694        158,210         89,294         41,694
# 4         238,795        260,097        164,499         85,098         37,856
# 5         121,454        120,486         76,151         46,633         20,789
# 6         129,764        130,139         88,022         46,494         21,435
# 7          96,799        112,192         70,616         31,398         11,533
# 8               0              0              0              0              0
# 9       1,069,026      1,079,916        631,839        346,583        170,939
# 10        116,951        133,463        100,443         70,685         38,601
# 11        123,289        133,302         94,841         61,257         36,391
# 12        168,032        171,484        124,177         86,621         59,585
# 13        141,846        153,580        117,059         84,246         51,351
# 14        139,558        161,882        124,212         99,766         61,498
# 15        209,641        229,880        177,853        120,901         74,513
# 16        273,474        291,053        202,106        117,903         64,839
# 17         47,115         49,375         32,080         22,342         11,038
#
#    2008년_남_80~89세  ... 2024년_여_10~19세  2024년_여_20~29세 2024년_여_30~39세  \
# 0         216,374  ...      2,245,507       2,855,132      3,166,585
# 1          35,212  ...        352,043         692,450        720,478
# 2          12,275  ...        127,955         175,150        188,127
# 3           8,512  ...        103,130         127,260        131,690
# 4           9,385  ...        132,857         169,872        201,668
# 5           4,782  ...         70,457          87,080         83,546
# 6           5,331  ...         65,758          92,510         89,525
# 7           2,282  ...         52,550          49,913         61,638
# 8               0  ...         25,969          18,201         29,798
# 9          40,151  ...        644,297         774,543        909,829
# 10          9,872  ...              0               0              0
# 11          9,039  ...         69,310          77,788         85,178
# 12         14,651  ...         97,599          98,109        114,382
# 13         13,254  ...              0               0              0
# 14         15,219  ...         76,182          74,519         79,651
# 15         19,200  ...        102,956         100,482        115,611
# 16         15,241  ...        151,435         133,107        161,437
# 17          1,968  ...         34,028          32,633         38,100
#
#    2024년_여_40~49세 2024년_여_50~59세 2024년_여_60~69세 2024년_여_70~79세 2024년_여_80~89세  \
# 0       3,796,703      4,315,099      3,968,224      2,254,795      1,326,374
# 1         700,244        755,144        698,464        423,979        210,875
# 2         233,041        274,368        297,863        184,530         92,007
# 3         173,617        214,102        196,231        114,083         63,905
# 4         230,963        259,061        233,050        113,641         62,357
# 5         109,984        122,831         99,320         57,591         30,963
# 6         106,590        122,250        106,338         57,153         31,288
# 7          83,718        101,267         86,836         39,799         18,526
# 8          39,218         27,332         19,457          9,276          5,336
# 9       1,084,852      1,170,670        957,531        484,298        273,431
# 10              0              0              0              0              0
# 11        108,037        132,800        130,168         71,638         48,905
# 12        148,832        165,521        164,043         98,938         71,172
# 13              0              0              0              0              0
# 14        109,608        142,041        150,979        104,464         82,391
# 15        164,827        212,556        226,185        140,665         99,327
# 16        238,017        285,869        270,105        151,651         95,952
# 17         52,038         57,629         48,431         26,866         17,471
#
#    2024년_여_90~99세 2024년_여_100세 이상
# 0         252,368           7,052
# 1          35,979           1,150
# 2          14,561             368
# 3          10,606             223
# 4          12,706             411
# 5           5,822             156
# 6           5,878             178
# 7           3,228              76
# 8           1,300              35
# 9          52,690           1,514
# 10              0               0
# 11          9,648             239
# 12         15,589             412
# 13              0               0
# 14         16,523             468
# 15         19,585             492
# 16         18,845             384
# 17          4,419             217
#
# [18 rows x 375 columns]

# %%
data = data.melt(id_vars=['행정구역'], var_name='타입', value_name='value')
data.tail(10)
# Out:
#                        행정구역               타입  value
# 6722  세종특별자치시  (3600000000)  2024년_여_100세 이상     35
# 6723      경기도  (4100000000)  2024년_여_100세 이상  1,514
# 6724      강원도  (4200000000)  2024년_여_100세 이상      0
# 6725     충청북도  (4300000000)  2024년_여_100세 이상    239
# 6726     충청남도  (4400000000)  2024년_여_100세 이상    412
# 6727     전라북도  (4500000000)  2024년_여_100세 이상      0
# 6728     전라남도  (4600000000)  2024년_여_100세 이상    468
# 6729     경상북도  (4700000000)  2024년_여_100세 이상    492
# 6730     경상남도  (4800000000)  2024년_여_100세 이상    384
# 6731  제주특별자치도  (5000000000)  2024년_여_100세 이상    217

# %%
data['행정구역'] = data['행정구역'].str.replace(r'\(\d+\)', '', regex=True)
# 정규식으로 전처리. r'\(\d+\)' => (, 반복되는 숫자, )를 빈칸으로
data
# Out:
#            행정구역               타입      value
# 0          전국       2008년_남_0~9세  2,647,788
# 1       서울특별시       2008년_남_0~9세    480,828
# 2       부산광역시       2008년_남_0~9세    153,939
# 3       대구광역시       2008년_남_0~9세    128,282
# 4       인천광역시       2008년_남_0~9세    146,064
# ...         ...              ...        ...
# 6727     전라북도    2024년_여_100세 이상          0
# 6728     전라남도    2024년_여_100세 이상        468
# 6729     경상북도    2024년_여_100세 이상        492
# 6730     경상남도    2024년_여_100세 이상        384
# 6731  제주특별자치도    2024년_여_100세 이상        217
#
# [6732 rows x 3 columns]

# %%
test1 = data['타입'].str.split('_')
print(type(test1), test1)
test2 = data['타입'].str.split('_', expand=True)
print(type(test2), test2)
data[['time','gender','age']] = data['타입'].str.split('_',expand=True)
del data['타입']
data.head()
# Out:
# <class 'pandas.core.series.Series'> 0          [2008년, 남, 0~9세]
# 1          [2008년, 남, 0~9세]
# 2          [2008년, 남, 0~9세]
# 3          [2008년, 남, 0~9세]
# 4          [2008년, 남, 0~9세]
#                ...
# 6727    [2024년, 여, 100세 이상]
# 6728    [2024년, 여, 100세 이상]
# 6729    [2024년, 여, 100세 이상]
# 6730    [2024년, 여, 100세 이상]
# 6731    [2024년, 여, 100세 이상]
# Name: 타입, Length: 6732, dtype: object
# <class 'pandas.core.frame.DataFrame'>           0  1        2
# 0     2008년  남     0~9세
# 1     2008년  남     0~9세
# 2     2008년  남     0~9세
# 3     2008년  남     0~9세
# 4     2008년  남     0~9세
# ...     ... ..      ...
# 6727  2024년  여  100세 이상
# 6728  2024년  여  100세 이상
# 6729  2024년  여  100세 이상
# 6730  2024년  여  100세 이상
# 6731  2024년  여  100세 이상
#
# [6732 rows x 3 columns]
#       행정구역      value   time gender   age
# 0     전국    2,647,788  2008년      남  0~9세
# 1  서울특별시      480,828  2008년      남  0~9세
# 2  부산광역시      153,939  2008년      남  0~9세
# 3  대구광역시      128,282  2008년      남  0~9세
# 4  인천광역시      146,064  2008년      남  0~9세

# %%
new_data = data.copy()
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6732 entries, 0 to 6731
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    6732 non-null   object
#  1   value   6732 non-null   object
#  2   time    6732 non-null   object
#  3   gender  6732 non-null   object
#  4   age     6732 non-null   object
# dtypes: object(5)
# memory usage: 263.1+ KB

# %%
new_data['value'].dtype
# Out:
# dtype('O')

# %%
new_data['value'] = new_data['value'].str.replace(',','').fillna(0).astype(int)
new_data.head(3)
# Out:
#       행정구역    value   time gender   age
# 0     전국    2647788  2008년      남  0~9세
# 1  서울특별시     480828  2008년      남  0~9세
# 2  부산광역시     153939  2008년      남  0~9세

# %%
print(new_data['value'].dtype, new_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6732 entries, 0 to 6731
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    6732 non-null   object
#  1   value   6732 non-null   int64
#  2   time    6732 non-null   object
#  3   gender  6732 non-null   object
#  4   age     6732 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 263.1+ KB
# int64 None

# %%
new_data['time'] = pd.to_datetime(new_data['time'], format="%Y년")
new_data.head(3)
# Out:
#       행정구역    value       time gender   age
# 0     전국    2647788 2008-01-01      남  0~9세
# 1  서울특별시     480828 2008-01-01      남  0~9세
# 2  부산광역시     153939 2008-01-01      남  0~9세

# %%
# new_data = new_data.drop(index=range(1))
new_data = new_data.drop(new_data.iloc[0:1].index)
new_data
# Out:
#            행정구역   value       time gender      age
# 1       서울특별시    480828 2008-01-01      남     0~9세
# 2       부산광역시    153939 2008-01-01      남     0~9세
# 3       대구광역시    128282 2008-01-01      남     0~9세
# 4       인천광역시    146064 2008-01-01      남     0~9세
# 5       광주광역시     86287 2008-01-01      남     0~9세
# ...         ...     ...        ...    ...      ...
# 6727     전라북도         0 2024-01-01      여  100세 이상
# 6728     전라남도       468 2024-01-01      여  100세 이상
# 6729     경상북도       492 2024-01-01      여  100세 이상
# 6730     경상남도       384 2024-01-01      여  100세 이상
# 6731  제주특별자치도       217 2024-01-01      여  100세 이상
#
# [6731 rows x 5 columns]

# %%
mydata = new_data.copy()
mydata
# Out:
#            행정구역   value       time gender      age
# 1       서울특별시    480828 2008-01-01      남     0~9세
# 2       부산광역시    153939 2008-01-01      남     0~9세
# 3       대구광역시    128282 2008-01-01      남     0~9세
# 4       인천광역시    146064 2008-01-01      남     0~9세
# 5       광주광역시     86287 2008-01-01      남     0~9세
# ...         ...     ...        ...    ...      ...
# 6727     전라북도         0 2024-01-01      여  100세 이상
# 6728     전라남도       468 2024-01-01      여  100세 이상
# 6729     경상북도       492 2024-01-01      여  100세 이상
# 6730     경상남도       384 2024-01-01      여  100세 이상
# 6731  제주특별자치도       217 2024-01-01      여  100세 이상
#
# [6731 rows x 5 columns]

# %%
# mfilter = mydata['time'] == '2008-01-01'
mfilter = mydata['time'].dt.year == 2008
mydata = mydata[mfilter]
mydata.sample(5)
# Out:
#           행정구역   value       time gender     age
# 44   세종특별자치시         0 2008-01-01      남  20~29세
# 133    울산광역시     11533 2008-01-01      남  70~79세
# 203    광주광역시     79439 2008-01-01      여    0~9세
# 145    서울특별시     35212 2008-01-01      남  80~89세
# 291    대구광역시    163136 2008-01-01      여  50~59세

# %%
mydata2 = mydata.groupby(['행정구역', 'age'])['value'].sum().reset_index()
mydata2.head(5)
# Out:
#     행정구역      age   value
# 0  강원도       0~9세  148237
# 1  강원도    100세 이상     101
# 2  강원도     10~19세  198539
# 3  강원도     20~29세  196588
# 4  강원도     30~39세  225353

# %%
# mydata2['per'] = mydata2.groupby(['행정구역'])['value'].transform(lambda x : 100 * x / float(x.sum()))
mydata2['per'] = mydata2.groupby(['행정구역'])['value'].apply(lambda x : 100 * x / float(x.sum())).reset_index(level=0, drop=True)
mydata2
# Out:
#        행정구역      age   value        per
# 0     강원도       0~9세  148237   9.826417
# 1     강원도    100세 이상     101   0.006695
# 2     강원도     10~19세  198539  13.160864
# 3     강원도     20~29세  196588  13.031535
# 4     강원도     30~39세  225353  14.938325
# ..      ...      ...     ...        ...
# 193  충청북도     50~59세  186114  12.247775
# 194  충청북도     60~69세  131196   8.633736
# 195  충청북도     70~79세   92194   6.067095
# 196  충청북도     80~89세   28407   1.869406
# 197  충청북도     90~99세    3439   0.226313
#
# [198 rows x 4 columns]

# %%
mydata2 = mydata2.dropna()
mydata2.sample(5)
# Out:
#         행정구역     age    value        per
# 151   전라남도    70~79세   163149   8.501865
# 124  인천광역시    20~29세   402627  14.952616
# 53   광주광역시    80~89세    17013   1.195828
# 143   전라남도      0~9세   185983   9.691768
# 139     전국    60~69세  3964796   8.455107

# %%
# piv_data = mydata2.pivot(index='행정구역', columns='age', values='value')
piv_data = mydata2.pivot(index='행정구역', columns='age', values='per')
# args = np.argsort(piv_data.columns.str.extract(r'()'))
piv_data
# Out:
# age             0~9세   100세 이상     10~19세     20~29세     30~39세     40~49세  \
# 행정구역
# 강원도         9.826417  0.006695  13.160864  13.031535  14.938325  17.152297
# 경기도        11.769968  0.003144  14.471334  14.060166  18.756455  18.483638
# 경상남도       10.754321  0.003442  14.085047  13.408137  16.543963  17.519362
# 경상북도        9.544311  0.005423  12.672468  13.325669  15.010096  16.591490
# 광주광역시      11.648729  0.004217  16.087344  15.170142  17.098663  16.992808
# 대구광역시       9.776059  0.002969  14.753249  14.571078  16.367515  18.329635
# 대전광역시      11.154441  0.003106  15.060943  15.277705  17.540195  17.629939
# 부산광역시       8.292300  0.003142  13.060614  15.359768  15.420926  17.562529
# 서울특별시       9.122003  0.003519  12.488473  16.677684  18.514887  16.879796
# 울산광역시      11.131537  0.001438  15.937242  14.412621  17.341135  19.600290
# 인천광역시      10.473186  0.003045  14.694138  14.952616  17.415733  18.995754
# 전국          5.222763  0.004436  14.554455  15.409000  18.063285  18.493108
# 전라남도        9.691768  0.010370  13.145428  12.149951  13.596136  15.814034
# 전라북도       10.080776  0.008676  13.903791  13.205856  14.709769  16.052615
# 제주특별자치도    11.874795  0.011059  14.619098  13.084536  16.361645  16.902657
# 충청남도       10.545423  0.006044  13.018962  13.527799  15.673623  16.146691
# 충청북도       10.427067  0.004936  13.951213  13.881654  15.713680  16.977126
#
# age           50~59세     60~69세    70~79세    80~89세    90~99세
# 행정구역
# 강원도        13.137729  10.011826  6.352565  2.108440  0.273308
# 경기도        10.888237   6.531846  3.747990  1.153228  0.133995
# 경상남도       12.334357   8.028263  5.473386  1.695810  0.153911
# 경상북도       13.223235   9.863357  7.157018  2.334337  0.272597
# 광주광역시      10.958842   6.957214  3.736427  1.195828  0.149786
# 대구광역시      12.891421   7.736674  4.249869  1.199296  0.122236
# 대전광역시      11.798581   6.580907  3.649157  1.167541  0.137485
# 부산광역시      15.193661   9.191875  4.509293  1.285961  0.119930
# 서울특별시      13.154922   8.114334  3.739990  1.161343  0.143048
# 울산광역시      12.177467   5.666811  2.749803  0.886456  0.095199
# 인천광역시      11.889429   6.622644  3.646433  1.174738  0.132284
# 전국         13.095049   8.455107  4.975317  1.548578  0.178903
# 전라남도       12.647038  11.450256  8.501865  2.679602  0.313552
# 전라북도       12.572531   9.851328  7.045415  2.299166  0.270078
# 제주특별자치도    11.327005   8.374181  5.384256  1.717397  0.343372
# 충청남도       12.125834   9.253589  7.215516  2.224446  0.262073
# 충청북도       12.247775   8.633736  6.067095  1.869406  0.226313

# %%
print(piv_data.columns)
templist = list(piv_data.columns)
templist.append(templist.pop(1))
piv_data = piv_data[templist]
piv_data
# Out:
# Index(['0~9세', '100세 이상', '10~19세', '20~29세', '30~39세', '40~49세', '50~59세',
#        '60~69세', '70~79세', '80~89세', '90~99세'],
#       dtype='object', name='age')
# age             0~9세     10~19세     20~29세     30~39세     40~49세     50~59세  \
# 행정구역
# 강원도         9.826417  13.160864  13.031535  14.938325  17.152297  13.137729
# 경기도        11.769968  14.471334  14.060166  18.756455  18.483638  10.888237
# 경상남도       10.754321  14.085047  13.408137  16.543963  17.519362  12.334357
# 경상북도        9.544311  12.672468  13.325669  15.010096  16.591490  13.223235
# 광주광역시      11.648729  16.087344  15.170142  17.098663  16.992808  10.958842
# 대구광역시       9.776059  14.753249  14.571078  16.367515  18.329635  12.891421
# 대전광역시      11.154441  15.060943  15.277705  17.540195  17.629939  11.798581
# 부산광역시       8.292300  13.060614  15.359768  15.420926  17.562529  15.193661
# 서울특별시       9.122003  12.488473  16.677684  18.514887  16.879796  13.154922
# 울산광역시      11.131537  15.937242  14.412621  17.341135  19.600290  12.177467
# 인천광역시      10.473186  14.694138  14.952616  17.415733  18.995754  11.889429
# 전국          5.222763  14.554455  15.409000  18.063285  18.493108  13.095049
# 전라남도        9.691768  13.145428  12.149951  13.596136  15.814034  12.647038
# 전라북도       10.080776  13.903791  13.205856  14.709769  16.052615  12.572531
# 제주특별자치도    11.874795  14.619098  13.084536  16.361645  16.902657  11.327005
# 충청남도       10.545423  13.018962  13.527799  15.673623  16.146691  12.125834
# 충청북도       10.427067  13.951213  13.881654  15.713680  16.977126  12.247775
#
# age           60~69세    70~79세    80~89세    90~99세   100세 이상
# 행정구역
# 강원도        10.011826  6.352565  2.108440  0.273308  0.006695
# 경기도         6.531846  3.747990  1.153228  0.133995  0.003144
# 경상남도        8.028263  5.473386  1.695810  0.153911  0.003442
# 경상북도        9.863357  7.157018  2.334337  0.272597  0.005423
# 광주광역시       6.957214  3.736427  1.195828  0.149786  0.004217
# 대구광역시       7.736674  4.249869  1.199296  0.122236  0.002969
# 대전광역시       6.580907  3.649157  1.167541  0.137485  0.003106
# 부산광역시       9.191875  4.509293  1.285961  0.119930  0.003142
# 서울특별시       8.114334  3.739990  1.161343  0.143048  0.003519
# 울산광역시       5.666811  2.749803  0.886456  0.095199  0.001438
# 인천광역시       6.622644  3.646433  1.174738  0.132284  0.003045
# 전국          8.455107  4.975317  1.548578  0.178903  0.004436
# 전라남도       11.450256  8.501865  2.679602  0.313552  0.010370
# 전라북도        9.851328  7.045415  2.299166  0.270078  0.008676
# 제주특별자치도     8.374181  5.384256  1.717397  0.343372  0.011059
# 충청남도        9.253589  7.215516  2.224446  0.262073  0.006044
# 충청북도        8.633736  6.067095  1.869406  0.226313  0.004936

# %%
# 2008년도 지역별 연령 분포 비교
plt.figure(figsize=(8,8))
plt.title("2008년도 지역별 연령 분포 비교")
sns.heatmap(piv_data, cmap="Oranges")
plt.savefig("2008년도 지역별 연령 분포 비교.png")
plt.show()

# %% [markdown]
# ## 2024년도 지역별 연령 분포 비교

# %%
hdfs = InsecureClient("http://namenode:9870", user="hadoop")
paths = ["202012_202412_연령별인구현황_연간.csv"]
datas = []
for path in paths:
    with hdfs.read(path, encoding="EUC-KR") as reader:
        datas.append(pd.read_csv(reader))
mdata = pd.merge(datas[0], datas[0], on="행정구역", how="left")
data = pd.merge(mdata, datas[0], on="행정구역", how="left")
data
# Out:
#                      행정구역 2020년_계_총인구수_x 2020년_계_연령구간인구수_x 2020년_계_0~9세_x  \
# 0        전국  (0000000000)     51,829,023        51,829,023      3,970,070
# 1     서울특별시  (1100000000)      9,668,465         9,668,465        623,745
# 2     부산광역시  (2600000000)      3,391,946         3,391,946        232,356
# 3     대구광역시  (2700000000)      2,418,346         2,418,346        178,226
# 4     인천광역시  (2800000000)      2,942,828         2,942,828        228,634
# 5     광주광역시  (2900000000)      1,450,062         1,450,062        119,692
# 6     대전광역시  (3000000000)      1,463,882         1,463,882        114,529
# 7     울산광역시  (3100000000)      1,136,017         1,136,017         98,506
# 8   세종특별자치시  (3600000000)        355,831           355,831         47,283
# 9       경기도  (4100000000)     13,427,014        13,427,014      1,145,984
# 10      강원도  (4200000000)      1,542,840         1,542,840        105,598
# 11  강원특별자치도  (5100000000)              0                 0              0
# 12     충청북도  (4300000000)      1,600,837         1,600,837        123,371
# 13     충청남도  (4400000000)      2,121,029         2,121,029        172,628
# 14     전라북도  (4500000000)      1,804,104         1,804,104        128,692
# 15  전북특별자치도  (5200000000)              0                 0              0
# 16     전라남도  (4600000000)      1,851,549         1,851,549        132,202
# 17     경상북도  (4700000000)      2,639,422         2,639,422        189,561
# 18     경상남도  (4800000000)      3,340,216         3,340,216        268,766
# 19  제주특별자치도  (5000000000)        674,635           674,635         60,297
#
#    2020년_계_10~19세_x 2020년_계_20~29세_x 2020년_계_30~39세_x 2020년_계_40~49세_x  \
# 0         4,793,336        6,806,153        6,873,117        8,294,787
# 1           781,866        1,460,411        1,475,106        1,528,182
# 2           272,014          430,987          419,014          511,148
# 3           225,898          321,534          294,310          383,839
# 4           274,162          401,546          406,146          483,977
# 5           157,144          209,375          185,867          240,867
# 6           146,436          212,488          194,088          237,216
# 7           112,420          144,569          151,705          187,808
# 8            42,677           37,453           61,492           68,831
# 9         1,328,214        1,807,848        1,907,459        2,299,423
# 10          137,508          180,015          166,349          224,378
# 11                0                0                0                0
# 12          149,379          199,209          194,677          241,194
# 13          202,548          243,200          268,598          327,791
# 14          174,963          211,464          189,012          268,277
# 15                0                0                0                0
# 16          167,308          200,709          186,064          259,749
# 17          225,924          284,163          291,117          383,508
# 18          324,214          378,436          399,558          536,223
# 19           70,661           82,746           82,555          112,376
#
#    2020년_계_50~59세_x 2020년_계_60~69세_x  ... 2024년_여_10~19세 2024년_여_20~29세  \
# 0         8,645,014        6,744,506  ...      2,245,507      2,855,132
# 1         1,523,556        1,243,954  ...        352,043        692,450
# 2           568,913          531,620  ...        127,955        175,150
# 3           425,479          325,957  ...        103,130        127,260
# 4           512,167          367,879  ...        132,857        169,872
# 5           233,822          163,784  ...         70,457         87,080
# 6           241,921          179,153  ...         65,758         92,510
# 7           209,521          145,347  ...         52,550         49,913
# 8            45,205           30,139  ...         25,969         18,201
# 9         2,234,920        1,532,434  ...        644,297        774,543
# 10          267,815          241,578  ...              0              0
# 11                0                0  ...         61,103         68,809
# 12          273,800          223,341  ...         69,310         77,788
# 13          340,183          279,372  ...         97,599         98,109
# 14          299,522          255,829  ...              0              0
# 15                0                0  ...         77,878         82,706
# 16          313,679          272,377  ...         76,182         74,519
# 17          459,662          409,250  ...        102,956        100,482
# 18          582,448          462,731  ...        151,435        133,107
# 19          112,401           79,761  ...         34,028         32,633
#
#    2024년_여_30~39세 2024년_여_40~49세 2024년_여_50~59세 2024년_여_60~69세 2024년_여_70~79세  \
# 0       3,166,585      3,796,703      4,315,099      3,968,224      2,254,795
# 1         720,478        700,244        755,144        698,464        423,979
# 2         188,127        233,041        274,368        297,863        184,530
# 3         131,690        173,617        214,102        196,231        114,083
# 4         201,668        230,963        259,061        233,050        113,641
# 5          83,546        109,984        122,831         99,320         57,591
# 6          89,525        106,590        122,250        106,338         57,153
# 7          61,638         83,718        101,267         86,836         39,799
# 8          29,798         39,218         27,332         19,457          9,276
# 9         909,829      1,084,852      1,170,670        957,531        484,298
# 10              0              0              0              0              0
# 11         73,555         98,596        126,442        139,085         79,534
# 12         85,178        108,037        132,800        130,168         71,638
# 13        114,382        148,832        165,521        164,043         98,938
# 14              0              0              0              0              0
# 15         82,372        114,521        145,216        144,138         96,689
# 16         79,651        109,608        142,041        150,979        104,464
# 17        115,611        164,827        212,556        226,185        140,665
# 18        161,437        238,017        285,869        270,105        151,651
# 19         38,100         52,038         57,629         48,431         26,866
#
#    2024년_여_80~89세 2024년_여_90~99세 2024년_여_100세 이상
# 0       1,326,374        252,368           7,052
# 1         210,875         35,979           1,150
# 2          92,007         14,561             368
# 3          63,905         10,606             223
# 4          62,357         12,706             411
# 5          30,963          5,822             156
# 6          31,288          5,878             178
# 7          18,526          3,228              76
# 8           5,336          1,300              35
# 9         273,431         52,690           1,514
# 10              0              0               0
# 11         54,666         10,605             322
# 12         48,905          9,648             239
# 13         71,172         15,589             412
# 14              0              0               0
# 15         67,802         14,384             407
# 16         82,391         16,523             468
# 17         99,327         19,585             492
# 18         95,952         18,845             384
# 19         17,471          4,419             217
#
# [20 rows x 586 columns]

# %%
data = data[data.columns[data.columns.str.contains("행정구역|년_남_|년_여_")]]
data = data[data.columns[~data.columns.str.contains("_총인구수|_연령구간인구수")]] # 물결 '~' 표시는 반대값
data
# Out:
#                      행정구역 2020년_남_0~9세_x 2020년_남_10~19세_x 2020년_남_20~29세_x  \
# 0        전국  (0000000000)      2,035,712        2,478,773        3,573,667
# 1     서울특별시  (1100000000)        320,275          401,285          707,669
# 2     부산광역시  (2600000000)        119,173          140,558          224,517
# 3     대구광역시  (2700000000)         91,285          118,103          171,675
# 4     인천광역시  (2800000000)        117,356          141,025          209,363
# 5     광주광역시  (2900000000)         61,487           81,458          109,335
# 6     대전광역시  (3000000000)         58,822           75,777          111,421
# 7     울산광역시  (3100000000)         50,619           59,174           81,200
# 8   세종특별자치시  (3600000000)         24,188           21,419           19,050
# 9       경기도  (4100000000)        586,787          682,846          951,737
# 10      강원도  (4200000000)         54,030           71,555          101,305
# 11  강원특별자치도  (5100000000)              0                0                0
# 12     충청북도  (4300000000)         63,068           77,703          110,849
# 13     충청남도  (4400000000)         88,428          105,190          134,208
# 14     전라북도  (4500000000)         66,002           90,603          114,209
# 15  전북특별자치도  (5200000000)              0                0                0
# 16     전라남도  (4600000000)         67,356           86,808          112,080
# 17     경상북도  (4700000000)         97,729          118,670          160,830
# 18     경상남도  (4800000000)        138,139          169,631          210,511
# 19  제주특별자치도  (5000000000)         30,968           36,968           43,708
#
#    2020년_남_30~39세_x 2020년_남_40~49세_x 2020년_남_50~59세_x 2020년_남_60~69세_x  \
# 0         3,541,548        4,214,971        4,362,544        3,298,604
# 1           737,901          756,950          748,582          587,294
# 2           214,297          257,288          276,068          251,584
# 3           153,070          189,358          208,340          155,170
# 4           210,025          247,402          256,037          182,261
# 5            94,869          119,545          115,860           78,051
# 6           101,293          118,238          120,638           87,060
# 7            80,565           95,644          106,610           73,250
# 8            30,004           35,188           23,494           14,935
# 9           982,843        1,168,836        1,132,305          761,522
# 10           87,423          115,276          137,661          120,154
# 11                0                0                0                0
# 12          103,283          124,974          140,958          111,733
# 13          144,598          174,709          179,676          139,575
# 14           97,465          138,330          154,888          126,312
# 15                0                0                0                0
# 16           97,929          138,946          168,090          137,191
# 17          155,283          200,206          237,742          202,941
# 18          208,912          276,112          297,249          230,016
# 19           41,788           57,969           58,346           39,555
#
#    2020년_남_70~79세_x 2020년_남_80~89세_x  ... 2024년_여_10~19세 2024년_여_20~29세  \
# 0         1,664,340          608,461  ...      2,245,507      2,855,132
# 1           320,416          108,339  ...        352,043        692,450
# 2           132,206           41,604  ...        127,955        175,150
# 3            76,599           27,260  ...        103,130        127,260
# 4            80,868           26,682  ...        132,857        169,872
# 5            41,434           13,995  ...         70,457         87,080
# 6            41,509           14,485  ...         65,758         92,510
# 7            28,575            7,503  ...         52,550         49,913
# 8             6,602            2,415  ...         25,969         18,201
# 9           347,382          126,549  ...        644,297        774,543
# 10           60,730           25,547  ...              0              0
# 11                0                0  ...         61,103         68,809
# 12           54,272           22,539  ...         69,310         77,788
# 13           77,607           35,055  ...         97,599         98,109
# 14           75,155           30,700  ...              0              0
# 15                0                0  ...         77,878         82,706
# 16           84,379           34,535  ...         76,182         74,519
# 17          107,476           44,291  ...        102,956        100,482
# 18          108,436           38,987  ...        151,435        133,107
# 19           20,694            7,975  ...         34,028         32,633
#
#    2024년_여_30~39세 2024년_여_40~49세 2024년_여_50~59세 2024년_여_60~69세 2024년_여_70~79세  \
# 0       3,166,585      3,796,703      4,315,099      3,968,224      2,254,795
# 1         720,478        700,244        755,144        698,464        423,979
# 2         188,127        233,041        274,368        297,863        184,530
# 3         131,690        173,617        214,102        196,231        114,083
# 4         201,668        230,963        259,061        233,050        113,641
# 5          83,546        109,984        122,831         99,320         57,591
# 6          89,525        106,590        122,250        106,338         57,153
# 7          61,638         83,718        101,267         86,836         39,799
# 8          29,798         39,218         27,332         19,457          9,276
# 9         909,829      1,084,852      1,170,670        957,531        484,298
# 10              0              0              0              0              0
# 11         73,555         98,596        126,442        139,085         79,534
# 12         85,178        108,037        132,800        130,168         71,638
# 13        114,382        148,832        165,521        164,043         98,938
# 14              0              0              0              0              0
# 15         82,372        114,521        145,216        144,138         96,689
# 16         79,651        109,608        142,041        150,979        104,464
# 17        115,611        164,827        212,556        226,185        140,665
# 18        161,437        238,017        285,869        270,105        151,651
# 19         38,100         52,038         57,629         48,431         26,866
#
#    2024년_여_80~89세 2024년_여_90~99세 2024년_여_100세 이상
# 0       1,326,374        252,368           7,052
# 1         210,875         35,979           1,150
# 2          92,007         14,561             368
# 3          63,905         10,606             223
# 4          62,357         12,706             411
# 5          30,963          5,822             156
# 6          31,288          5,878             178
# 7          18,526          3,228              76
# 8           5,336          1,300              35
# 9         273,431         52,690           1,514
# 10              0              0               0
# 11         54,666         10,605             322
# 12         48,905          9,648             239
# 13         71,172         15,589             412
# 14              0              0               0
# 15         67,802         14,384             407
# 16         82,391         16,523             468
# 17         99,327         19,585             492
# 18         95,952         18,845             384
# 19         17,471          4,419             217
#
# [20 rows x 331 columns]

# %%
data = data.melt(id_vars=['행정구역'], var_name='타입', value_name='value')
data.tail(10)
# Out:
#                        행정구역               타입 value
# 6590      강원도  (4200000000)  2024년_여_100세 이상     0
# 6591  강원특별자치도  (5100000000)  2024년_여_100세 이상   322
# 6592     충청북도  (4300000000)  2024년_여_100세 이상   239
# 6593     충청남도  (4400000000)  2024년_여_100세 이상   412
# 6594     전라북도  (4500000000)  2024년_여_100세 이상     0
# 6595  전북특별자치도  (5200000000)  2024년_여_100세 이상   407
# 6596     전라남도  (4600000000)  2024년_여_100세 이상   468
# 6597     경상북도  (4700000000)  2024년_여_100세 이상   492
# 6598     경상남도  (4800000000)  2024년_여_100세 이상   384
# 6599  제주특별자치도  (5000000000)  2024년_여_100세 이상   217

# %%
data['행정구역'] = data['행정구역'].str.replace(r'\(\d+\)', '', regex=True)
data['타입'] = data['타입'].str.replace('_x', '', regex=True)
# 정규식으로 전처리. r'\(\d+\)' => (, 반복되는 숫자, )를 빈칸으로
data
# Out:
#            행정구역               타입      value
# 0          전국       2020년_남_0~9세  2,035,712
# 1       서울특별시       2020년_남_0~9세    320,275
# 2       부산광역시       2020년_남_0~9세    119,173
# 3       대구광역시       2020년_남_0~9세     91,285
# 4       인천광역시       2020년_남_0~9세    117,356
# ...         ...              ...        ...
# 6595  전북특별자치도    2024년_여_100세 이상        407
# 6596     전라남도    2024년_여_100세 이상        468
# 6597     경상북도    2024년_여_100세 이상        492
# 6598     경상남도    2024년_여_100세 이상        384
# 6599  제주특별자치도    2024년_여_100세 이상        217
#
# [6600 rows x 3 columns]

# %%
test1 = data['타입'].str.split('_')
print(type(test1), test1)
test2 = data['타입'].str.split('_', expand=True)
print(type(test2), test2)
data[['time','gender','age','xx']] = data['타입'].str.split('_',expand=True)
del data['타입']
data.head()
# Out:
# <class 'pandas.core.series.Series'> 0          [2020년, 남, 0~9세]
# 1          [2020년, 남, 0~9세]
# 2          [2020년, 남, 0~9세]
# 3          [2020년, 남, 0~9세]
# 4          [2020년, 남, 0~9세]
#                ...
# 6595    [2024년, 여, 100세 이상]
# 6596    [2024년, 여, 100세 이상]
# 6597    [2024년, 여, 100세 이상]
# 6598    [2024년, 여, 100세 이상]
# 6599    [2024년, 여, 100세 이상]
# Name: 타입, Length: 6600, dtype: object
# <class 'pandas.core.frame.DataFrame'>           0  1        2     3
# 0     2020년  남     0~9세  None
# 1     2020년  남     0~9세  None
# 2     2020년  남     0~9세  None
# 3     2020년  남     0~9세  None
# 4     2020년  남     0~9세  None
# ...     ... ..      ...   ...
# 6595  2024년  여  100세 이상  None
# 6596  2024년  여  100세 이상  None
# 6597  2024년  여  100세 이상  None
# 6598  2024년  여  100세 이상  None
# 6599  2024년  여  100세 이상  None
#
# [6600 rows x 4 columns]
#       행정구역      value   time gender   age    xx
# 0     전국    2,035,712  2020년      남  0~9세  None
# 1  서울특별시      320,275  2020년      남  0~9세  None
# 2  부산광역시      119,173  2020년      남  0~9세  None
# 3  대구광역시       91,285  2020년      남  0~9세  None
# 4  인천광역시      117,356  2020년      남  0~9세  None

# %%
new_data2 = data.copy()
new_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6600 entries, 0 to 6599
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    6600 non-null   object
#  1   value   6600 non-null   object
#  2   time    6600 non-null   object
#  3   gender  6600 non-null   object
#  4   age     6600 non-null   object
#  5   xx      2200 non-null   object
# dtypes: object(6)
# memory usage: 309.5+ KB

# %%
new_data2['value'].dtype
# Out:
# dtype('O')

# %%
new_data2['value'] = new_data2['value'].str.replace(',','').fillna(0).astype(int)
new_data2.head(3)
# Out:
#       행정구역    value   time gender   age    xx
# 0     전국    2035712  2020년      남  0~9세  None
# 1  서울특별시     320275  2020년      남  0~9세  None
# 2  부산광역시     119173  2020년      남  0~9세  None

# %%
print(new_data2['value'].dtype, new_data2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6600 entries, 0 to 6599
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    6600 non-null   object
#  1   value   6600 non-null   int64
#  2   time    6600 non-null   object
#  3   gender  6600 non-null   object
#  4   age     6600 non-null   object
#  5   xx      2200 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 309.5+ KB
# int64 None

# %%
new_data2['time'] = pd.to_datetime(new_data2['time'], format="%Y년")
new_data2.head(3)
# Out:
#       행정구역    value       time gender   age    xx
# 0     전국    2035712 2020-01-01      남  0~9세  None
# 1  서울특별시     320275 2020-01-01      남  0~9세  None
# 2  부산광역시     119173 2020-01-01      남  0~9세  None

# %%
# new_data = new_data.drop(index=range(1))
new_data2 = new_data2.drop(new_data2.iloc[0:1].index)
new_data2
# Out:
#            행정구역   value       time gender      age    xx
# 1       서울특별시    320275 2020-01-01      남     0~9세  None
# 2       부산광역시    119173 2020-01-01      남     0~9세  None
# 3       대구광역시     91285 2020-01-01      남     0~9세  None
# 4       인천광역시    117356 2020-01-01      남     0~9세  None
# 5       광주광역시     61487 2020-01-01      남     0~9세  None
# ...         ...     ...        ...    ...      ...   ...
# 6595  전북특별자치도       407 2024-01-01      여  100세 이상  None
# 6596     전라남도       468 2024-01-01      여  100세 이상  None
# 6597     경상북도       492 2024-01-01      여  100세 이상  None
# 6598     경상남도       384 2024-01-01      여  100세 이상  None
# 6599  제주특별자치도       217 2024-01-01      여  100세 이상  None
#
# [6599 rows x 6 columns]

# %%
mydata24 = new_data.copy()
mydata24
# Out:
#            행정구역   value       time gender      age
# 1       서울특별시    480828 2008-01-01      남     0~9세
# 2       부산광역시    153939 2008-01-01      남     0~9세
# 3       대구광역시    128282 2008-01-01      남     0~9세
# 4       인천광역시    146064 2008-01-01      남     0~9세
# 5       광주광역시     86287 2008-01-01      남     0~9세
# ...         ...     ...        ...    ...      ...
# 6727     전라북도         0 2024-01-01      여  100세 이상
# 6728     전라남도       468 2024-01-01      여  100세 이상
# 6729     경상북도       492 2024-01-01      여  100세 이상
# 6730     경상남도       384 2024-01-01      여  100세 이상
# 6731  제주특별자치도       217 2024-01-01      여  100세 이상
#
# [6731 rows x 5 columns]

# %%
# mfilter = mydata['time'] == '2008-01-01'
mfilter = mydata24['time'].dt.year == 2024
mydata24 = mydata24[mfilter]
mydata24.sample(5)
# Out:
#            행정구역   value       time gender     age
# 6369     경상북도    112797 2024-01-01      남  10~19세
# 6560  세종특별자치시     25969 2024-01-01      여  10~19세
# 6625    서울특별시    755144 2024-01-01      여  50~59세
# 6366     충청남도    104188 2024-01-01      남  10~19세
# 6416  세종특별자치시     37875 2024-01-01      남  40~49세

# %%
mydata22 = mydata24.groupby(['행정구역', 'age'])['value'].sum().reset_index()
mydata22.head(25)
# Out:
#       행정구역      age    value
# 0    강원도       0~9세        0
# 1    강원도    100세 이상        0
# 2    강원도     10~19세        0
# 3    강원도     20~29세        0
# 4    강원도     30~39세        0
# 5    강원도     40~49세        0
# 6    강원도     50~59세        0
# 7    강원도     60~69세        0
# 8    강원도     70~79세        0
# 9    강원도     80~89세        0
# 10   강원도     90~99세        0
# 11   경기도       0~9세   939988
# 12   경기도    100세 이상     1947
# 13   경기도     10~19세  1318307
# 14   경기도     20~29세  1627548
# 15   경기도     30~39세  1907383
# 16   경기도     40~49세  2214874
# 17   경기도     50~59세  2357607
# 18   경기도     60~69세  1911010
# 19   경기도     70~79세   905114
# 20   경기도     80~89세   440674
# 21   경기도     90~99세    70233
# 22  경상남도       0~9세   195007
# 23  경상남도    100세 이상      451
# 24  경상남도     10~19세   314142

# %%
# mydata2['per'] = mydata2.groupby(['행정구역'])['value'].transform(lambda x : 100 * x / float(x.sum()))
mydata22['per'] = mydata22.groupby(['행정구역'])['value'].apply(lambda x : 100 * x / float(x.sum())).reset_index(level=0, drop=True)
mydata22
# Out:
#        행정구역      age   value        per
# 0     강원도       0~9세       0        NaN
# 1     강원도    100세 이상       0        NaN
# 2     강원도     10~19세       0        NaN
# 3     강원도     20~29세       0        NaN
# 4     강원도     30~39세       0        NaN
# ..      ...      ...     ...        ...
# 193  충청북도     50~59세  273441  17.184826
# 194  충청북도     60~69세  264085  16.596834
# 195  충청북도     70~79세  135995   8.546818
# 196  충청북도     80~89세   76117   4.783692
# 197  충청북도     90~99세   12378   0.777915
#
# [198 rows x 4 columns]

# %%
mydata22 = mydata22.dropna()
mydata22.sample(5)
# Out:
#           행정구역      age   value        per
# 96     서울특별시     70~79세  773771   8.291741
# 70     대전광역시     30~39세  190937  13.267281
# 119    울산광역시     80~89세   29297   2.668096
# 100  세종특별자치시    100세 이상      39   0.009982
# 146     전라남도     20~29세  169229   9.460376

# %%
# piv_data = mydata2.pivot(index='행정구역', columns='age', values='value')
piv_data2 = mydata22.pivot(index='행정구역', columns='age', values='per')
# args = np.argsort(piv_data.columns.str.extract(r'()'))
piv_data2
# Out:
# age             0~9세   100세 이상     10~19세     20~29세     30~39세     40~49세  \
# 행정구역
# 경기도         6.863889  0.014217   9.626413  11.884523  13.927907  16.173238
# 경상남도        6.040398  0.013970   9.730639   9.468619  10.708993  15.163519
# 경상북도        5.540763  0.021767   8.523124   9.315892  10.103682  13.589404
# 광주광역시       6.591561  0.012851  10.324888  12.924606  12.337353  15.585599
# 대구광역시       6.017357  0.011000   8.987790  11.342728  11.957545  14.581180
# 대전광역시       6.358792  0.014939   9.423086  13.443287  13.267281  14.807974
# 부산광역시       5.563464  0.013133   8.046659  10.971292  11.907128  14.423905
# 서울특별시       5.184193  0.015903   7.723749  14.019333  15.459618  14.830428
# 세종특별자치시    10.584230  0.009982  13.447918   9.491022  15.056119  19.732777
# 울산광역시       6.656989  0.007832   9.960393  10.669560  12.412288  15.772338
# 인천광역시       6.461283  0.016749   9.022678  11.631739  13.972148  15.742848
# 전국          6.130981  0.016746   9.018968  11.628229  12.934249  15.078567
# 전라남도        5.666756  0.030243   8.745323   9.460376   9.455624  13.011154
# 제주특별자치도     7.123848  0.034608  10.481109  10.443368  11.573941  15.695558
# 충청남도        6.333317  0.022840   9.444419  10.309402  11.810450  14.883594
# 충청북도        6.148719  0.017848   8.986807  10.919338  11.895220  14.141984
#
# age           50~59세     60~69세     70~79세    80~89세    90~99세
# 행정구역
# 경기도        17.215489  13.954392   6.609236  3.217847  0.512849
# 경상남도       18.113078  16.745736   8.818386  4.471407  0.725255
# 경상북도       17.432717  18.070313  10.468147  5.950184  0.984007
# 광주광역시      17.264286  13.535503   7.350283  3.532606  0.540463
# 대구광역시      17.692328  15.887857   8.679154  4.252190  0.590871
# 대전광역시      16.939292  14.345898   7.360212  3.495171  0.544069
# 부산광역시      16.453968  17.176647  10.311860  4.550483  0.581461
# 서울특별시      15.924726  14.211996   8.291741  3.806864  0.531450
# 세종특별자치시    14.623034   9.927179   4.551493  2.153141  0.423103
# 울산광역시      18.485332  15.956027   7.040669  2.668096  0.370475
# 인천광역시      17.099679  15.223187   7.034733  3.255600  0.539356
# 전국         16.998911  15.265926   8.174198  4.109055  0.644168
# 전라남도       17.235785  17.424848  10.924582  6.888455  1.156853
# 제주특별자치도    17.815737  14.468620   7.446656  4.090589  0.825964
# 충청남도       16.538486  15.684643   8.813502  5.196263  0.963084
# 충청북도       17.184826  16.596834   8.546818  4.783692  0.777915

# %%
print(piv_data2.columns)
templist = list(piv_data2.columns)
templist.append(templist.pop(1))
piv_data2 = piv_data2[templist]
piv_data2
# Out:
# Index(['0~9세', '100세 이상', '10~19세', '20~29세', '30~39세', '40~49세', '50~59세',
#        '60~69세', '70~79세', '80~89세', '90~99세'],
#       dtype='object', name='age')
# age             0~9세     10~19세     20~29세     30~39세     40~49세     50~59세  \
# 행정구역
# 경기도         6.863889   9.626413  11.884523  13.927907  16.173238  17.215489
# 경상남도        6.040398   9.730639   9.468619  10.708993  15.163519  18.113078
# 경상북도        5.540763   8.523124   9.315892  10.103682  13.589404  17.432717
# 광주광역시       6.591561  10.324888  12.924606  12.337353  15.585599  17.264286
# 대구광역시       6.017357   8.987790  11.342728  11.957545  14.581180  17.692328
# 대전광역시       6.358792   9.423086  13.443287  13.267281  14.807974  16.939292
# 부산광역시       5.563464   8.046659  10.971292  11.907128  14.423905  16.453968
# 서울특별시       5.184193   7.723749  14.019333  15.459618  14.830428  15.924726
# 세종특별자치시    10.584230  13.447918   9.491022  15.056119  19.732777  14.623034
# 울산광역시       6.656989   9.960393  10.669560  12.412288  15.772338  18.485332
# 인천광역시       6.461283   9.022678  11.631739  13.972148  15.742848  17.099679
# 전국          6.130981   9.018968  11.628229  12.934249  15.078567  16.998911
# 전라남도        5.666756   8.745323   9.460376   9.455624  13.011154  17.235785
# 제주특별자치도     7.123848  10.481109  10.443368  11.573941  15.695558  17.815737
# 충청남도        6.333317   9.444419  10.309402  11.810450  14.883594  16.538486
# 충청북도        6.148719   8.986807  10.919338  11.895220  14.141984  17.184826
#
# age           60~69세     70~79세    80~89세    90~99세   100세 이상
# 행정구역
# 경기도        13.954392   6.609236  3.217847  0.512849  0.014217
# 경상남도       16.745736   8.818386  4.471407  0.725255  0.013970
# 경상북도       18.070313  10.468147  5.950184  0.984007  0.021767
# 광주광역시      13.535503   7.350283  3.532606  0.540463  0.012851
# 대구광역시      15.887857   8.679154  4.252190  0.590871  0.011000
# 대전광역시      14.345898   7.360212  3.495171  0.544069  0.014939
# 부산광역시      17.176647  10.311860  4.550483  0.581461  0.013133
# 서울특별시      14.211996   8.291741  3.806864  0.531450  0.015903
# 세종특별자치시     9.927179   4.551493  2.153141  0.423103  0.009982
# 울산광역시      15.956027   7.040669  2.668096  0.370475  0.007832
# 인천광역시      15.223187   7.034733  3.255600  0.539356  0.016749
# 전국         15.265926   8.174198  4.109055  0.644168  0.016746
# 전라남도       17.424848  10.924582  6.888455  1.156853  0.030243
# 제주특별자치도    14.468620   7.446656  4.090589  0.825964  0.034608
# 충청남도       15.684643   8.813502  5.196263  0.963084  0.022840
# 충청북도       16.596834   8.546818  4.783692  0.777915  0.017848

# %%
# 2024년도 지역별 연령 분포 비교
plt.figure(figsize=(8,8))
plt.title("2024년도 지역별 연령 분포 비교")
sns.heatmap(piv_data2, cmap="Blues")
plt.savefig("2024년도 지역별 연령 분포 비교.png")
plt.show()
